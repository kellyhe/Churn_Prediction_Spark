# %% [markdown]
# # Sparkify Project - Predicting churn rates
# This project aims to predict churn rates of Sparkify users. The smaller subset (128MB) of the full dataset (12GB) is explored before deploying on the cloud.
#
# The analysis includes four sections:
# 1. Load and Clean Dataset
# 2. Exploratory Data Analysis
# 3. Feature Engineering
# 4. Modelling and Evaluation

# %%
# import libraries
from pyspark.sql import SparkSession
from pyspark.sql.functions import avg, col, concat, desc, asc, sum, min, max, split, udf,to_date \
                                , concat_ws,first,last,countDistinct,when,count,datediff,trim,split\
                                , element_at ,row_number,explode, array, lit, create_map
from pyspark.sql.types import StringType,IntegerType,DoubleType
from pyspark.sql import Window

from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier, GBTClassifier,LinearSVC
from pyspark.ml.evaluation import MulticlassClassificationEvaluator,BinaryClassificationEvaluator
from pyspark.ml.feature import StandardScaler, StringIndexer,VectorAssembler
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.mllib.evaluation import MulticlassMetrics
from pyspark.ml.stat import Correlation
from itertools import chain

import re

import datetime
import time

import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; 
warnings.simplefilter('ignore')

# %%
# create a Spark session
spark = SparkSession.builder \
    .master("local") \
    .appName("Sparkify Analysis") \
    .getOrCreate()

# %%
spark.version
# Out:
# '3.0.1'

# %% [markdown]
# # Load and Clean Dataset
# Load and clean the small dataset file `mini_sparkify_event_data.json` first before deploying to the Spark Cluster.

# %%
#read json data
data_path = 'mini_sparkify_event_data.json'
df = spark.read.json(data_path)
df.persist()
# Out:
# DataFrame[artist: string, auth: string, firstName: string, gender: string, itemInSession: bigint, lastName: string, length: double, level: string, location: string, method: string, page: string, registration: bigint, sessionId: bigint, song: string, status: bigint, ts: bigint, userAgent: string, userId: string]

# %%
#look at the first record
df.head()
# Out:
# Row(artist='Martha Tilston', auth='Logged In', firstName='Colin', gender='M', itemInSession=50, lastName='Freeman', length=277.89016, level='paid', location='Bakersfield, CA', method='PUT', page='NextSong', registration=1538173362000, sessionId=29, song='Rockpools', status=200, ts=1538352117000, userAgent='Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0', userId='30')

# %%
#print schema
df.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %%
#check missing values for each column
df.select(*(sum(col(c).isNull().cast("int")).alias(c) for c in df.columns)).collect()
# Out:
# [Row(artist=58392, auth=0, firstName=8346, gender=8346, itemInSession=0, lastName=8346, length=58392, level=0, location=8346, method=0, page=0, registration=8346, sessionId=0, song=58392, status=0, ts=0, userAgent=8346, userId=0)]

# %%
#check blank user ID
df.select("userId").dropDuplicates().sort("userId").show()
# Out:
# +------+
# |userId|
# +------+
# |      |
# |    10|
# |   100|
# |100001|
# |100002|
# |100003|
# |100004|
# |100005|
# |100006|
# |100007|
# |100008|
# |100009|
# |100010|
# |100011|
# |100012|
# |100013|
# |100014|
# |100015|
# |100016|
# |100017|
# +------+
# only showing top 20 rows

# %%
#explore users with missing user id
df.filter(df.userId == "").groupby('auth').count().show()
# Out:
# +----------+-----+
# |      auth|count|
# +----------+-----+
# |Logged Out| 8249|
# |     Guest|   97|
# +----------+-----+

# %%
#check blank session ID
df.describe("sessionId").show()
# Out:
# +-------+-----------------+
# |summary|        sessionId|
# +-------+-----------------+
# |  count|           286500|
# |   mean|1041.526554973822|
# | stddev|726.7762634630741|
# |    min|                1|
# |    max|             2474|
# +-------+-----------------+

# %%
#check data size
df.count()
# Out:
# 286500

# %%
#exclude users with blank user id because they are mainly logged out users or Guest, which means no churn info.
df_valid = df.filter(df["userId"] != "")

# %%
#check data size again
df_valid.count()
# Out:
# 278154

# %% [markdown]
# # Exploratory Data Analysis
# Even when working with the full dataset, we should perform EDA by loading a small subset of the data and doing basic manipulations within Spark. In this step, I will explore the small subset of data first.

# %% [markdown]
# ### Define Churn
# I use the `Cancellation Confirmation` events to define churn, which happen for both paid and free users. Among 225 users in this small dataset, 52 users submit the cancellation confirmation.

# %%
# page events
df_valid.select("page").dropDuplicates().sort("page").show()
# Out:
# +--------------------+
# |                page|
# +--------------------+
# |               About|
# |          Add Friend|
# |     Add to Playlist|
# |              Cancel|
# |Cancellation Conf...|
# |           Downgrade|
# |               Error|
# |                Help|
# |                Home|
# |              Logout|
# |            NextSong|
# |         Roll Advert|
# |       Save Settings|
# |            Settings|
# |    Submit Downgrade|
# |      Submit Upgrade|
# |         Thumbs Down|
# |           Thumbs Up|
# |             Upgrade|
# +--------------------+

# %%
#total users
df_valid.select(col('userId')).dropDuplicates().count()
# Out:
# 225

# %%
#churn users
df_valid.filter(df.page == "Cancellation Confirmation").groupby('level').count().show()
# Out:
# +-----+-----+
# |level|count|
# +-----+-----+
# | free|   21|
# | paid|   31|
# +-----+-----+

# %%
#flag Cancellation Confirmation event
flag_cancel_event = udf(lambda x: 1 if x == "Cancellation Confirmation" else 0, IntegerType())
df_valid = df_valid.withColumn("Cancellation", flag_cancel_event("page"))
df_valid.filter(df_valid.page =='Cancellation Confirmation').head()
# Out:
# Row(artist=None, auth='Cancelled', firstName='Adriel', gender='M', itemInSession=104, lastName='Mendoza', length=None, level='paid', location='Kansas City, MO-KS', method='GET', page='Cancellation Confirmation', registration=1535623466000, sessionId=514, song=None, status=200, ts=1538943990000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"', userId='18', Cancellation=1)

# %%
#define Churn users
windowval = Window.partitionBy("userId")
df_valid = df_valid.withColumn("Churn", max("Cancellation").over(windowval))

# %%
#check user example
#df_valid.select(["userId", "firstname", "ts", "page", "Cancellation", "Churn"])\
#.where(df_valid.userId == "18").sort("ts").collect()

# %% [markdown]
# ### Explore Data
# Then perform some exploratory data analysis to observe the behavior for users who stayed vs users who churned using Spark SQL.

# %%
#create temperate view for all data
df_valid.createOrReplaceTempView("df_valid")

# %%
#group size in mini data
spark.sql("SELECT Churn, COUNT(DISTINCT userID) \
            FROM df_valid \
            group by Churn").show()
# Out:
# +-----+----------------------+
# |Churn|count(DISTINCT userID)|
# +-----+----------------------+
# |    1|                    52|
# |    0|                   173|
# +-----+----------------------+

# %%
#create temperate view for group size
spark.sql("SELECT Churn, COUNT(DISTINCT userID) as total_mem \
            FROM df_valid \
            group by Churn").createOrReplaceTempView("size")

# %%
#gender explore
spark.sql("SELECT a.Churn, gender, COUNT(DISTINCT userID) as mem \
           , COUNT(DISTINCT userID)/total_mem as percent\
            FROM df_valid as a join size on a.churn = size.churn\
            group by a.Churn,gender,total_mem \
            order by 1,2").show()
#62% of Users who churned are males.
# Out:
# +-----+------+---+-------------------+
# |Churn|gender|mem|            percent|
# +-----+------+---+-------------------+
# |    0|     F| 84|0.48554913294797686|
# |    0|     M| 89| 0.5144508670520231|
# |    1|     F| 20|0.38461538461538464|
# |    1|     M| 32| 0.6153846153846154|
# +-----+------+---+-------------------+

# %%
#action explore
spark.sql("select nvl(a.page, b.page) as page \
          , a.churn_mem, churn_percent \
          , b.not_churn_mem, not_churn_percent from \
           (SELECT page, COUNT(DISTINCT userID) churn_mem \
            , COUNT(DISTINCT userID)/total_mem as churn_percent\
            FROM df_valid as c join size on c.churn = size.churn\
            where c.Churn =1 \
            group by page,total_mem) a\
            full join \
           (SELECT page,COUNT(DISTINCT userID) not_churn_mem \
           , COUNT(DISTINCT userID)/total_mem as not_churn_percent\
            FROM df_valid as nc join size on nc.churn = size.churn\
            where nc.Churn =0 \
            group by page,total_mem) b\
            on a.page = b.page \
            order by 2 desc \
            ").show()
#Users who churned have higher % in action: Roll Advert, Thumbs Down 
#and lower % in action: Thumbs Up, Add Friend, Upgrade, Error,Help
# Out:
# +--------------------+---------+-------------------+-------------+-------------------+
# |                page|churn_mem|      churn_percent|not_churn_mem|  not_churn_percent|
# +--------------------+---------+-------------------+-------------+-------------------+
# |            NextSong|       52|                1.0|          173|                1.0|
# |              Cancel|       52|                1.0|         null|               null|
# |Cancellation Conf...|       52|                1.0|         null|               null|
# |                Home|       51| 0.9807692307692307|          172| 0.9942196531791907|
# |     Add to Playlist|       50| 0.9615384615384616|          165|  0.953757225433526|
# |         Roll Advert|       50| 0.9615384615384616|          157| 0.9075144508670521|
# |           Thumbs Up|       50| 0.9615384615384616|          170| 0.9826589595375722|
# |         Thumbs Down|       48| 0.9230769230769231|          155| 0.8959537572254336|
# |              Logout|       46| 0.8846153846153846|          167| 0.9653179190751445|
# |          Add Friend|       44| 0.8461538461538461|          162| 0.9364161849710982|
# |            Settings|       43| 0.8269230769230769|          152| 0.8786127167630058|
# |                Help|       43| 0.8269230769230769|          149|  0.861271676300578|
# |             Upgrade|       37| 0.7115384615384616|          131| 0.7572254335260116|
# |           Downgrade|       35| 0.6730769230769231|          119| 0.6878612716763006|
# |               About|       31| 0.5961538461538461|          124| 0.7167630057803468|
# |       Save Settings|       30| 0.5769230769230769|          102| 0.5895953757225434|
# |      Submit Upgrade|       29| 0.5576923076923077|          102| 0.5895953757225434|
# |               Error|       22| 0.4230769230769231|           95| 0.5491329479768786|
# |    Submit Downgrade|        9|0.17307692307692307|           40|0.23121387283236994|
# +--------------------+---------+-------------------+-------------+-------------------+

# %%
#artist explore
spark.sql("select nvl(a.artist, b.artist) as artist \
          , a.churn_mem, churn_percent \
          , b.not_churn_mem, not_churn_percent from \
           (SELECT artist, COUNT(DISTINCT userID) churn_mem \
            , COUNT(DISTINCT userID)/total_mem as churn_percent\
            FROM df_valid as c join size on c.churn = size.churn\
            where c.Churn =1 \
            group by artist,total_mem) a\
            full join \
           (SELECT artist,COUNT(DISTINCT userID) not_churn_mem \
           , COUNT(DISTINCT userID)/total_mem as not_churn_percent\
            FROM df_valid as nc join size on nc.churn = size.churn\
            where nc.Churn =0 \
            group by artist,total_mem) b\
            on a.artist = b.artist \
            order by 2 desc \
            ").show()
#Users who churned have lower % in top 20 artists
# Out:
# +--------------------+---------+------------------+-------------+------------------+
# |              artist|churn_mem|     churn_percent|not_churn_mem| not_churn_percent|
# +--------------------+---------+------------------+-------------+------------------+
# |                null|       52|               1.0|         null|              null|
# |Florence + The Ma...|       43|0.8269230769230769|          144|0.8323699421965318|
# |       Kings Of Leon|       42|0.8076923076923077|          157|0.9075144508670521|
# |       Dwight Yoakam|       41|0.7884615384615384|          148|0.8554913294797688|
# |            Coldplay|       40|0.7692307692307693|          149| 0.861271676300578|
# |            BjÃÂ¶rk|       39|              0.75|          140|0.8092485549132948|
# |      The Black Keys|       38|0.7307692307692307|          141| 0.815028901734104|
# |       Guns N' Roses|       37|0.7115384615384616|          133|0.7687861271676301|
# |       Justin Bieber|       37|0.7115384615384616|          140|0.8092485549132948|
# |           Radiohead|       37|0.7115384615384616|          130|0.7514450867052023|
# |     Alliance Ethnik|       36|0.6923076923076923|          136|0.7861271676300579|
# |        Taylor Swift|       36|0.6923076923076923|          137| 0.791907514450867|
# |              Eminem|       36|0.6923076923076923|          133|0.7687861271676301|
# |         The Killers|       36|0.6923076923076923|          132|0.7630057803468208|
# |         Linkin Park|       36|0.6923076923076923|          127|0.7341040462427746|
# |Barry Tuckwell/Ac...|       36|0.6923076923076923|          128|0.7398843930635838|
# |          John Mayer|       35|0.6730769230769231|          131|0.7572254335260116|
# |           Metallica|       35|0.6730769230769231|          133|0.7687861271676301|
# |                Muse|       35|0.6730769230769231|          131|0.7572254335260116|
# |            Harmonia|       34|0.6538461538461539|          138|0.7976878612716763|
# +--------------------+---------+------------------+-------------+------------------+
# only showing top 20 rows

# %%
#song explore
spark.sql("select nvl(a.song, b.song) as song \
          , a.churn_mem, churn_percent \
          , b.not_churn_mem, not_churn_percent from \
           (SELECT song, COUNT(DISTINCT userID) churn_mem \
            , COUNT(DISTINCT userID)/total_mem as churn_percent\
            FROM df_valid as c join size on c.churn = size.churn\
            where c.Churn =1 \
            group by song,total_mem) a\
            full join \
           (SELECT song,COUNT(DISTINCT userID) not_churn_mem \
           , COUNT(DISTINCT userID)/total_mem as not_churn_percent\
            FROM df_valid as nc join size on nc.churn = size.churn\
            where nc.Churn =0 \
            group by song,total_mem) b\
            on a.song = b.song\
            order by 2 desc \
            ").show()
#Users who churned have lower % in top 20 songs
# Out:
# +--------------------+---------+-------------------+-------------+------------------+
# |                song|churn_mem|      churn_percent|not_churn_mem| not_churn_percent|
# +--------------------+---------+-------------------+-------------+------------------+
# |                null|       52|                1.0|         null|              null|
# |      You're The One|       41| 0.7884615384615384|          149| 0.861271676300578|
# |             Revelry|       40| 0.7692307692307693|          137| 0.791907514450867|
# |                Undo|       39|               0.75|          137| 0.791907514450867|
# |Horn Concerto No....|       36| 0.6923076923076923|          128|0.7398843930635838|
# |Dog Days Are Over...|       36| 0.6923076923076923|          126|0.7283236994219653|
# |       Sehr kosmisch|       34| 0.6538461538461539|          138|0.7976878612716763|
# |              Canada|       32| 0.6153846153846154|          108|0.6242774566473989|
# |        Use Somebody|       29| 0.5576923076923077|          126|0.7283236994219653|
# |      Drop The World|       28| 0.5384615384615384|           90|0.5202312138728323|
# |       ReprÃÂ©sente|       28| 0.5384615384615384|          106|0.6127167630057804|
# |             Invalid|       28| 0.5384615384615384|          102|0.5895953757225434|
# |          Love Story|       27| 0.5192307692307693|          106|0.6127167630057804|
# |    Ain't Misbehavin|       26|                0.5|          112|0.6473988439306358|
# |SinceritÃÂ© Et J...|       26|                0.5|          114|0.6589595375722543|
# |    Hey_ Soul Sister|       26|                0.5|          106|0.6127167630057804|
# |            The Gift|       25| 0.4807692307692308|          105|0.6069364161849711|
# |          Tighten Up|       25| 0.4807692307692308|           60|0.3468208092485549|
# |    Somebody To Love|       25| 0.4807692307692308|          103|0.5953757225433526|
# |             Secrets|       24|0.46153846153846156|          120|0.6936416184971098|
# +--------------------+---------+-------------------+-------------+------------------+
# only showing top 20 rows

# %%
#location explore
spark.sql("select nvl(a.location, b.location) as location \
          , a.churn_mem, churn_percent \
          , b.not_churn_mem, not_churn_percent from \
           (SELECT location, COUNT(DISTINCT userID) churn_mem \
            , COUNT(DISTINCT userID)/total_mem as churn_percent\
            FROM df_valid as c join size on c.churn = size.churn\
            where c.Churn =1 \
            group by location,total_mem) a\
            full join \
           (SELECT location,COUNT(DISTINCT userID) not_churn_mem \
           , COUNT(DISTINCT userID)/total_mem as not_churn_percent\
            FROM df_valid as nc join size on nc.churn = size.churn\
            where nc.Churn =0 \
            group by location,total_mem) b\
            on a.location = b.location\
            order by 2 desc \
            ").show()
# location data seems very sparse
# Out:
# +--------------------+---------+--------------------+-------------+--------------------+
# |            location|churn_mem|       churn_percent|not_churn_mem|   not_churn_percent|
# +--------------------+---------+--------------------+-------------+--------------------+
# |New York-Newark-J...|        5| 0.09615384615384616|           10|0.057803468208092484|
# |Los Angeles-Long ...|        3|0.057692307692307696|           13| 0.07514450867052024|
# |Miami-Fort Lauder...|        2|0.038461538461538464|            3|0.017341040462427744|
# |Spokane-Spokane V...|        2|0.038461538461538464|         null|                null|
# |         Jackson, MS|        2|0.038461538461538464|         null|                null|
# |Phoenix-Mesa-Scot...|        2|0.038461538461538464|            5|0.028901734104046242|
# |Philadelphia-Camd...|        2|0.038461538461538464|            3|0.017341040462427744|
# |           Flint, MI|        2|0.038461538461538464|         null|                null|
# |Birmingham-Hoover...|        1|0.019230769230769232|         null|                null|
# |  Corpus Christi, TX|        1|0.019230769230769232|         null|                null|
# |Oxnard-Thousand O...|        1|0.019230769230769232|         null|                null|
# |San Francisco-Oak...|        1|0.019230769230769232|            1|0.005780346820809248|
# |New Philadelphia-...|        1|0.019230769230769232|         null|                null|
# |Orlando-Kissimmee...|        1|0.019230769230769232|         null|                null|
# |   Memphis, TN-MS-AR|        1|0.019230769230769232|         null|                null|
# |           Selma, AL|        1|0.019230769230769232|         null|                null|
# |Greenville-Anders...|        1|0.019230769230769232|            1|0.005780346820809248|
# |Indianapolis-Carm...|        1|0.019230769230769232|            1|0.005780346820809248|
# |    St. Louis, MO-IL|        1|0.019230769230769232|            5|0.028901734104046242|
# |          Albany, OR|        1|0.019230769230769232|         null|                null|
# +--------------------+---------+--------------------+-------------+--------------------+
# only showing top 20 rows

# %%
#state explore
spark.sql("select nvl(a.state, b.state) as state\
          , a.churn_mem, churn_percent \
          , b.not_churn_mem, not_churn_percent from \
           (SELECT right(location,2) as state, COUNT(DISTINCT userID) churn_mem \
            , COUNT(DISTINCT userID)/total_mem as churn_percent\
            FROM df_valid as c join size on c.churn = size.churn\
            where c.Churn =1 \
            group by state,total_mem) a\
            full join \
           (SELECT right(location,2) as state,COUNT(DISTINCT userID) not_churn_mem \
           , COUNT(DISTINCT userID)/total_mem as not_churn_percent\
            FROM df_valid as nc join size on nc.churn = size.churn\
            where nc.Churn =0 \
            group by state,total_mem) b\
            on a.state = b.state\
            order by 2 desc \
            ").show()
# States data is also very sparse, CA have relatively more users
# Out:
# +-----+---------+--------------------+-------------+--------------------+
# |state|churn_mem|       churn_percent|not_churn_mem|   not_churn_percent|
# +-----+---------+--------------------+-------------+--------------------+
# |   CA|        6| 0.11538461538461539|           27| 0.15606936416184972|
# |   PA|        5| 0.09615384615384616|           13| 0.07514450867052024|
# |   MD|        3|0.057692307692307696|            4|0.023121387283236993|
# |   MI|        3|0.057692307692307696|            2|0.011560693641618497|
# |   TX|        3|0.057692307692307696|           13| 0.07514450867052024|
# |   FL|        3|0.057692307692307696|           11| 0.06358381502890173|
# |   CO|        2|0.038461538461538464|            2|0.011560693641618497|
# |   MS|        2|0.038461538461538464|            1|0.005780346820809248|
# |   AZ|        2|0.038461538461538464|            5|0.028901734104046242|
# |   AL|        2|0.038461538461538464|            4|0.023121387283236993|
# |   WA|        2|0.038461538461538464|            4|0.023121387283236993|
# |   KY|        2|0.038461538461538464|            1|0.005780346820809248|
# |   OH|        2|0.038461538461538464|            1|0.005780346820809248|
# |   NC|        2|0.038461538461538464|            7| 0.04046242774566474|
# |   AR|        2|0.038461538461538464|         null|                null|
# |   IL|        1|0.019230769230769232|            8|0.046242774566473986|
# |   OR|        1|0.019230769230769232|         null|                null|
# |   LA|        1|0.019230769230769232|            1|0.005780346820809248|
# |   IN|        1|0.019230769230769232|            5|0.028901734104046242|
# |   MT|        1|0.019230769230769232|            1|0.005780346820809248|
# +-----+---------+--------------------+-------------+--------------------+
# only showing top 20 rows

# %%
#avg artists/songs by user
spark.sql("select churn,count(distinct artist)/count(distinct userid) avg_artists, \
           count(distinct song)/count(distinct userid) avg_songs, \
           count(distinct location)/count(distinct userid) avg_locations, \
           count(distinct right(location,2))/count(distinct userid) avg_states \
           from df_valid \
           group by churn \
          ").show()
#Users who churned heard more artists/songs and switched more locations?? maybe different enroll length?
# Out:
# +-----+------------------+------------------+------------------+-------------------+
# |churn|       avg_artists|         avg_songs|     avg_locations|         avg_states|
# +-----+------------------+------------------+------------------+-------------------+
# |    1|161.57692307692307|369.53846153846155|0.7692307692307693|                0.5|
# |    0| 96.25433526011561| 308.3005780346821|0.5433526011560693|0.20809248554913296|
# +-----+------------------+------------------+------------------+-------------------+

# %%
#add date time
get_year = udf(lambda x: datetime.datetime.fromtimestamp(x / 1000.0).year)
get_month = udf(lambda x: datetime.datetime.fromtimestamp(x / 1000.0).month)
get_day = udf(lambda x: datetime.datetime.fromtimestamp(x / 1000.0).day)
get_hour = udf(lambda x: datetime.datetime.fromtimestamp(x / 1000.0).hour)
df_valid = df_valid.withColumn("year",get_year("ts"))
df_valid = df_valid.withColumn("month",get_month("ts"))
df_valid = df_valid.withColumn("day",get_day("ts"))
df_valid = df_valid.withColumn("hour",get_hour("ts"))
df_valid = df_valid.withColumn("date", to_date(concat_ws("-", "year", "month", "day")))

# %%
#check user example
df_valid.filter(df_valid.userId=='100010').sort("ts").collect()
# Out:
# [Row(artist='Sleeping With Sirens', auth='Logged In', firstName='Darianna', gender='F', itemInSession=0, lastName='Carpenter', length=202.97098, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Captain Tyin Knots VS Mr Walkway (No Way)', status=200, ts=1539003534000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='12', date=datetime.date(2018, 10, 8)),
#  Row(artist='Francesca Battistelli', auth='Logged In', firstName='Darianna', gender='F', itemInSession=1, lastName='Carpenter', length=196.54485, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Beautiful_ Beautiful (Album)', status=200, ts=1539003736000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Brutha', auth='Logged In', firstName='Darianna', gender='F', itemInSession=2, lastName='Carpenter', length=263.13098, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song="She's Gone", status=200, ts=1539003932000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=3, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='Thumbs Up', registration=1538016340000, sessionId=31, song=None, status=307, ts=1539003933000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Josh Ritter', auth='Logged In', firstName='Darianna', gender='F', itemInSession=4, lastName='Carpenter', length=316.23791, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Folk Bloodbath', status=200, ts=1539004195000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='LMFAO', auth='Logged In', firstName='Darianna', gender='F', itemInSession=5, lastName='Carpenter', length=183.74485, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Yes', status=200, ts=1539004511000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='OneRepublic', auth='Logged In', firstName='Darianna', gender='F', itemInSession=6, lastName='Carpenter', length=224.67873, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Secrets', status=200, ts=1539004694000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Dwight Yoakam', auth='Logged In', firstName='Darianna', gender='F', itemInSession=7, lastName='Carpenter', length=239.3073, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song="You're The One", status=200, ts=1539004918000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=8, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=31, song=None, status=200, ts=1539004961000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='The Chordettes', auth='Logged In', firstName='Darianna', gender='F', itemInSession=9, lastName='Carpenter', length=142.41914, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Mr Sandman', status=200, ts=1539005157000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Coko featuring Kirk Franklin', auth='Logged In', firstName='Darianna', gender='F', itemInSession=10, lastName='Carpenter', length=249.3122, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='I Get Joy', status=200, ts=1539005299000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='The Cure', auth='Logged In', firstName='Darianna', gender='F', itemInSession=11, lastName='Carpenter', length=52.27057, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='The Final Sound', status=200, ts=1539005548000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=12, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=31, song=None, status=200, ts=1539005571000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Kid Cudi Vs Crookers', auth='Logged In', firstName='Darianna', gender='F', itemInSession=13, lastName='Carpenter', length=162.97751, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song="Day 'N' Nite", status=200, ts=1539005600000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=14, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='Thumbs Up', registration=1538016340000, sessionId=31, song=None, status=307, ts=1539005601000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Yeasayer', auth='Logged In', firstName='Darianna', gender='F', itemInSession=15, lastName='Carpenter', length=323.44771, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='2080', status=200, ts=1539005762000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Ben Lee', auth='Logged In', firstName='Darianna', gender='F', itemInSession=16, lastName='Carpenter', length=245.78567, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Ache For You', status=200, ts=1539006085000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=17, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=31, song=None, status=200, ts=1539006103000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='? & The Mysterians', auth='Logged In', firstName='Darianna', gender='F', itemInSession=18, lastName='Carpenter', length=128.10404, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Just Like A Rose', status=200, ts=1539006330000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=19, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=31, song=None, status=200, ts=1539006331000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Angels and Airwaves', auth='Logged In', firstName='Darianna', gender='F', itemInSession=20, lastName='Carpenter', length=302.05342, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='The Gift', status=200, ts=1539006458000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=21, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=31, song=None, status=200, ts=1539006503000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Karramba', auth='Logged In', firstName='Darianna', gender='F', itemInSession=22, lastName='Carpenter', length=177.10975, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Erni & Berni', status=200, ts=1539006760000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Biffy Clyro', auth='Logged In', firstName='Darianna', gender='F', itemInSession=23, lastName='Carpenter', length=203.33669, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Mountains', status=200, ts=1539006937000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Dr. Dre / Eminem / Alvin Joiner', auth='Logged In', firstName='Darianna', gender='F', itemInSession=24, lastName='Carpenter', length=244.21832, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song="What's The Difference", status=200, ts=1539007140000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='13', date=datetime.date(2018, 10, 8)),
#  Row(artist='Tamia', auth='Logged In', firstName='Darianna', gender='F', itemInSession=25, lastName='Carpenter', length=243.09506, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Officially Missing You (Radio Version)', status=200, ts=1539007384000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='Stanislaw Soyka', auth='Logged In', firstName='Darianna', gender='F', itemInSession=26, lastName='Carpenter', length=115.30404, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='W Zlobie Lezy', status=200, ts=1539007627000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='fIREHOSE', auth='Logged In', firstName='Darianna', gender='F', itemInSession=27, lastName='Carpenter', length=99.23873, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='It Matters', status=200, ts=1539007742000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='Marilyn Manson', auth='Logged In', firstName='Darianna', gender='F', itemInSession=28, lastName='Carpenter', length=338.18077, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Coma White', status=200, ts=1539007841000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='Redman', auth='Logged In', firstName='Darianna', gender='F', itemInSession=29, lastName='Carpenter', length=250.72281, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Rock Da Spot', status=200, ts=1539008179000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='Anberlin', auth='Logged In', firstName='Darianna', gender='F', itemInSession=30, lastName='Carpenter', length=204.32934, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='The Feel Good Drag', status=200, ts=1539008429000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='Songs: Ohia', auth='Logged In', firstName='Darianna', gender='F', itemInSession=31, lastName='Carpenter', length=330.34404, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Trouble Will Find You', status=200, ts=1539008633000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=32, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=31, song=None, status=200, ts=1539008656000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='The Crests', auth='Logged In', firstName='Darianna', gender='F', itemInSession=33, lastName='Carpenter', length=182.88281, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='16 Candles', status=200, ts=1539008963000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='Vinicio Capossela', auth='Logged In', firstName='Darianna', gender='F', itemInSession=34, lastName='Carpenter', length=202.94485, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Il Ballo Di San Vito', status=200, ts=1539009145000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='BjÃ\x83Â¶rk', auth='Logged In', firstName='Darianna', gender='F', itemInSession=35, lastName='Carpenter', length=348.57751, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Undo', status=200, ts=1539009347000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='Alejandra Guzman', auth='Logged In', firstName='Darianna', gender='F', itemInSession=36, lastName='Carpenter', length=241.60608, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Mirala_ Miralo', status=200, ts=1539009695000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='David Crowder*Band', auth='Logged In', firstName='Darianna', gender='F', itemInSession=37, lastName='Carpenter', length=241.89342, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Only You (Illuminate Album Version)', status=200, ts=1539009936000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='Marumari', auth='Logged In', firstName='Darianna', gender='F', itemInSession=38, lastName='Carpenter', length=253.59628, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=31, song='Baby M', status=200, ts=1539010177000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=39, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=31, song=None, status=200, ts=1539010247000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='8', hour='14', date=datetime.date(2018, 10, 8)),
#  Row(artist='The Black Keys', auth='Logged In', firstName='Darianna', gender='F', itemInSession=0, lastName='Carpenter', length=206.47138, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=78, song='Give Your Heart Away', status=200, ts=1539603322000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='15', hour='11', date=datetime.date(2018, 10, 15)),
#  Row(artist='Michael Jackson', auth='Logged In', firstName='Darianna', gender='F', itemInSession=1, lastName='Carpenter', length=297.40363, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=78, song='The Way You Make Me Feel', status=200, ts=1539603528000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='15', hour='11', date=datetime.date(2018, 10, 15)),
#  Row(artist='California Swag District', auth='Logged In', firstName='Darianna', gender='F', itemInSession=2, lastName='Carpenter', length=239.17669, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=78, song='Teach Me How To Dougie', status=200, ts=1539603825000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='15', hour='11', date=datetime.date(2018, 10, 15)),
#  Row(artist='Pixies', auth='Logged In', firstName='Darianna', gender='F', itemInSession=3, lastName='Carpenter', length=229.3024, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=78, song='Where Is My Mind?', status=200, ts=1539604064000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='15', hour='11', date=datetime.date(2018, 10, 15)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=4, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Home', registration=1538016340000, sessionId=78, song=None, status=200, ts=1539604089000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='15', hour='11', date=datetime.date(2018, 10, 15)),
#  Row(artist='Tegan And Sara', auth='Logged In', firstName='Darianna', gender='F', itemInSession=5, lastName='Carpenter', length=159.65995, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=78, song='Like O_ Like H (Album Version)', status=200, ts=1539604293000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='15', hour='11', date=datetime.date(2018, 10, 15)),
#  Row(artist='The Almost', auth='Logged In', firstName='Darianna', gender='F', itemInSession=6, lastName='Carpenter', length=222.24934, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=78, song='Dirty And Left Out', status=200, ts=1539604452000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='15', hour='11', date=datetime.date(2018, 10, 15)),
#  Row(artist='Darren Styles', auth='Logged In', firstName='Darianna', gender='F', itemInSession=7, lastName='Carpenter', length=243.30404, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=78, song='Paradise & Dreams', status=200, ts=1539604674000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='15', hour='11', date=datetime.date(2018, 10, 15)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=8, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='Logout', registration=1538016340000, sessionId=78, song=None, status=307, ts=1539604675000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='15', hour='11', date=datetime.date(2018, 10, 15)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=1, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Home', registration=1538016340000, sessionId=113, song=None, status=200, ts=1539699018000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Jeremih', auth='Logged In', firstName='Darianna', gender='F', itemInSession=2, lastName='Carpenter', length=227.26485, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Birthday Sex', status=200, ts=1539699018000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Goldfinger', auth='Logged In', firstName='Darianna', gender='F', itemInSession=3, lastName='Carpenter', length=141.34812, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='I Want (Album Version)', status=200, ts=1539699245000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=4, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=113, song=None, status=200, ts=1539699253000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=5, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=113, song=None, status=200, ts=1539699258000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Paramore', auth='Logged In', firstName='Darianna', gender='F', itemInSession=6, lastName='Carpenter', length=267.65016, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='The Only Exception (Album Version)', status=200, ts=1539699386000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Ben Folds Five', auth='Logged In', firstName='Darianna', gender='F', itemInSession=7, lastName='Carpenter', length=250.20036, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='One Angry Dwarf And 200 Solemn Faces', status=200, ts=1539699653000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Hopes Die Last', auth='Logged In', firstName='Darianna', gender='F', itemInSession=8, lastName='Carpenter', length=221.04771, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Call Me Sick Boy', status=200, ts=1539699903000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=9, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=113, song=None, status=200, ts=1539699985000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='David Bowie', auth='Logged In', firstName='Darianna', gender='F', itemInSession=10, lastName='Carpenter', length=279.09179, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Pallas Athena (2003 Digital Remaster)', status=200, ts=1539700124000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=11, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='Add to Playlist', registration=1538016340000, sessionId=113, song=None, status=200, ts=1539700125000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Danny Wilson', auth='Logged In', firstName='Darianna', gender='F', itemInSession=12, lastName='Carpenter', length=266.60526, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Broken China', status=200, ts=1539700403000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=13, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='Logout', registration=1538016340000, sessionId=113, song=None, status=307, ts=1539700404000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=16, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Home', registration=1538016340000, sessionId=113, song=None, status=200, ts=1539700458000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Rammstein', auth='Logged In', firstName='Darianna', gender='F', itemInSession=17, lastName='Carpenter', length=217.0771, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Ich Will', status=200, ts=1539700669000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Ke$ha', auth='Logged In', firstName='Darianna', gender='F', itemInSession=18, lastName='Carpenter', length=175.17669, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Dinosaur', status=200, ts=1539700886000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Imogen Heap', auth='Logged In', firstName='Darianna', gender='F', itemInSession=19, lastName='Carpenter', length=249.05098, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Have You Got It In You?', status=200, ts=1539701061000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='The Everly Brothers', auth='Logged In', firstName='Darianna', gender='F', itemInSession=20, lastName='Carpenter', length=121.36444, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Wake Up Little Suzie', status=200, ts=1539701310000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=21, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Help', registration=1538016340000, sessionId=113, song=None, status=200, ts=1539701346000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Lamb Of God', auth='Logged In', firstName='Darianna', gender='F', itemInSession=22, lastName='Carpenter', length=306.99057, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Beating On Deaths Door', status=200, ts=1539701431000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=23, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='Thumbs Up', registration=1538016340000, sessionId=113, song=None, status=307, ts=1539701432000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Flight Of The Conchords', auth='Logged In', firstName='Darianna', gender='F', itemInSession=24, lastName='Carpenter', length=166.50404, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Foux du Fafa (Album Version)', status=200, ts=1539701737000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Paramore', auth='Logged In', firstName='Darianna', gender='F', itemInSession=25, lastName='Carpenter', length=267.65016, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='The Only Exception (Album Version)', status=200, ts=1539701903000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='14', date=datetime.date(2018, 10, 16)),
#  Row(artist='Mindless Faith', auth='Logged In', firstName='Darianna', gender='F', itemInSession=26, lastName='Carpenter', length=312.47628, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Independence Day (version)', status=200, ts=1539702170000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='15', date=datetime.date(2018, 10, 16)),
#  Row(artist='The Smiths', auth='Logged In', firstName='Darianna', gender='F', itemInSession=27, lastName='Carpenter', length=250.27873, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Asleep', status=200, ts=1539702482000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='15', date=datetime.date(2018, 10, 16)),
#  Row(artist='opm', auth='Logged In', firstName='Darianna', gender='F', itemInSession=28, lastName='Carpenter', length=188.29016, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song="Love Don't", status=200, ts=1539702732000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='15', date=datetime.date(2018, 10, 16)),
#  Row(artist='Pepper', auth='Logged In', firstName='Darianna', gender='F', itemInSession=29, lastName='Carpenter', length=327.49669, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Stormtrooper (LP Version)', status=200, ts=1539702920000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='15', date=datetime.date(2018, 10, 16)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=30, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Home', registration=1538016340000, sessionId=113, song=None, status=200, ts=1539702931000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='15', date=datetime.date(2018, 10, 16)),
#  Row(artist='tobyMac', auth='Logged In', firstName='Darianna', gender='F', itemInSession=31, lastName='Carpenter', length=242.88608, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song="Boomin' / Opera Trip Interlude (Portable Sounds Album Version)", status=200, ts=1539703247000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='15', date=datetime.date(2018, 10, 16)),
#  Row(artist='Craig David', auth='Logged In', firstName='Darianna', gender='F', itemInSession=32, lastName='Carpenter', length=287.21587, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='Rise & Fall [Feat. Sting]', status=200, ts=1539703489000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='15', date=datetime.date(2018, 10, 16)),
#  Row(artist='Interpol', auth='Logged In', firstName='Darianna', gender='F', itemInSession=33, lastName='Carpenter', length=302.8371, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=113, song='PDA (E.P Version)', status=200, ts=1539703776000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='10', day='16', hour='15', date=datetime.date(2018, 10, 16)),
# ...
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=9, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=187, song=None, status=200, ts=1542819128000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='16', date=datetime.date(2018, 11, 21)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=10, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Upgrade', registration=1538016340000, sessionId=187, song=None, status=200, ts=1542819143000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='16', date=datetime.date(2018, 11, 21)),
#  Row(artist='Heidi Berry', auth='Logged In', firstName='Darianna', gender='F', itemInSession=11, lastName='Carpenter', length=228.46649, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Time', status=200, ts=1542819393000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='16', date=datetime.date(2018, 11, 21)),
#  Row(artist='Hit The Lights', auth='Logged In', firstName='Darianna', gender='F', itemInSession=12, lastName='Carpenter', length=61.85751, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Count It!', status=200, ts=1542819621000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='Kanye West', auth='Logged In', firstName='Darianna', gender='F', itemInSession=13, lastName='Carpenter', length=237.47873, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Flashing Lights', status=200, ts=1542819682000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='Usher featuring BeyoncÃ\x83Â©', auth='Logged In', firstName='Darianna', gender='F', itemInSession=14, lastName='Carpenter', length=260.25751, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Love In This Club Part II', status=200, ts=1542819919000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=15, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='Thumbs Down', registration=1538016340000, sessionId=187, song=None, status=307, ts=1542819920000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='Drowning Pool', auth='Logged In', firstName='Darianna', gender='F', itemInSession=16, lastName='Carpenter', length=258.16771, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Up Side Down (Explicit)', status=200, ts=1542820179000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=17, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='Thumbs Up', registration=1538016340000, sessionId=187, song=None, status=307, ts=1542820180000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='Sev Statik', auth='Logged In', firstName='Darianna', gender='F', itemInSession=18, lastName='Carpenter', length=214.80444, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='MIC (Speak Life Album Version)', status=200, ts=1542820437000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='T.I.', auth='Logged In', firstName='Darianna', gender='F', itemInSession=19, lastName='Carpenter', length=299.75465, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Dead And Gone [feat. Justin Timberlake] (Explicit Album Version)', status=200, ts=1542820651000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='Nick Cave & The Bad Seeds', auth='Logged In', firstName='Darianna', gender='F', itemInSession=20, lastName='Carpenter', length=367.15057, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='We Came Along This Road', status=200, ts=1542820950000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='Bob James', auth='Logged In', firstName='Darianna', gender='F', itemInSession=21, lastName='Carpenter', length=345.05098, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Angela (Theme From "Taxi")', status=200, ts=1542821317000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='Kelly Clarkson', auth='Logged In', firstName='Darianna', gender='F', itemInSession=22, lastName='Carpenter', length=281.5473, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Already Gone', status=200, ts=1542821662000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='DJ Khaled', auth='Logged In', firstName='Darianna', gender='F', itemInSession=23, lastName='Carpenter', length=227.082, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='All I Do Is Win (feat. T-Pain_ Ludacris_ Snoop Dogg & Rick Ross)', status=200, ts=1542821943000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=24, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='Thumbs Up', registration=1538016340000, sessionId=187, song=None, status=307, ts=1542821944000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='Gwen Stefani', auth='Logged In', firstName='Darianna', gender='F', itemInSession=25, lastName='Carpenter', length=264.93342, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Luxurious', status=200, ts=1542822170000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='Ke$ha', auth='Logged In', firstName='Darianna', gender='F', itemInSession=26, lastName='Carpenter', length=207.64689, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Kiss N Tell', status=200, ts=1542822434000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='The Police', auth='Logged In', firstName='Darianna', gender='F', itemInSession=27, lastName='Carpenter', length=305.05751, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Walking On The Moon', status=200, ts=1542822641000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='Eminem', auth='Logged In', firstName='Darianna', gender='F', itemInSession=28, lastName='Carpenter', length=302.57587, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Taking My Ball', status=200, ts=1542822946000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='17', date=datetime.date(2018, 11, 21)),
#  Row(artist='Hot Chip', auth='Logged In', firstName='Darianna', gender='F', itemInSession=29, lastName='Carpenter', length=319.42485, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Alley Cats', status=200, ts=1542823248000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='18', date=datetime.date(2018, 11, 21)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=30, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='GET', page='Roll Advert', registration=1538016340000, sessionId=187, song=None, status=200, ts=1542823257000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='18', date=datetime.date(2018, 11, 21)),
#  Row(artist='Hermano', auth='Logged In', firstName='Darianna', gender='F', itemInSession=31, lastName='Carpenter', length=115.90485, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Letters From Madrid', status=200, ts=1542823567000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='18', date=datetime.date(2018, 11, 21)),
#  Row(artist='John Waite', auth='Logged In', firstName='Darianna', gender='F', itemInSession=32, lastName='Carpenter', length=269.76608, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='Missing You', status=200, ts=1542823682000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='18', date=datetime.date(2018, 11, 21)),
#  Row(artist='Lily Allen', auth='Logged In', firstName='Darianna', gender='F', itemInSession=33, lastName='Carpenter', length=185.25995, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='NextSong', registration=1538016340000, sessionId=187, song='22', status=200, ts=1542823951000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='18', date=datetime.date(2018, 11, 21)),
#  Row(artist=None, auth='Logged In', firstName='Darianna', gender='F', itemInSession=34, lastName='Carpenter', length=None, level='free', location='Bridgeport-Stamford-Norwalk, CT', method='PUT', page='Logout', registration=1538016340000, sessionId=187, song=None, status=307, ts=1542823952000, userAgent='"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"', userId='100010', Cancellation=0, Churn=0, year='2018', month='11', day='21', hour='18', date=datetime.date(2018, 11, 21))]

# %%
#recreate view for all data
df_valid.createOrReplaceTempView("df_valid")

# %%
#create temperate view for enroll length
spark.sql("select churn,userid,datediff(max(date),min(date)) enroll_days \
           ,count(distinct date) active_days \
           from df_valid \
           group by churn,userid \
          ").createOrReplaceTempView("enroll_length")

# %%
#avg enroll days, active days, active ratio by churn group
spark.sql("select churn, avg(enroll_days),avg(active_days),avg(active_days/enroll_days) as avg_active_ratio \
          from enroll_length \
          group by churn \
          ").show()
#Users who churned have fewer avg enroll_days and active days but higher active_ratio
# Out:
# +-----+-----------------+------------------+------------------+
# |churn| avg(enroll_days)|  avg(active_days)|  avg_active_ratio|
# +-----+-----------------+------------------+------------------+
# |    1|23.46153846153846| 9.826923076923077| 0.567671094359117|
# |    0|46.93063583815029|15.104046242774567|0.3200569146027875|
# +-----+-----------------+------------------+------------------+

# %%
#avg artists/songs/locations by user and enroll length
spark.sql("select churn,\
           round(count(distinct artist)/sum(enroll_days),4) artists_per_enrollday, \
           round(count(distinct song)/sum(enroll_days),4) songs_per_enrollday, \
           round(count(distinct location)/sum(enroll_days),6) locations_per_enrollday, \
           round(count(distinct artist)/sum(active_days),4) artists_per_activeday, \
           round(count(distinct song)/sum(active_days),4) songs_per_activeday, \
           round(count(distinct location)/sum(active_days),6) locations_per_activeday \
           from df_valid a join enroll_length b on a.userid = b.userid \
           group by churn \
          ").show()
#Users who churned still heard more artists/songs and switched more locations per enrolled day or active day
# Out:
# +-----+---------------------+-------------------+-----------------------+---------------------+-------------------+-----------------------+
# |churn|artists_per_enrollday|songs_per_enrollday|locations_per_enrollday|artists_per_activeday|songs_per_activeday|locations_per_activeday|
# +-----+---------------------+-------------------+-----------------------+---------------------+-------------------+-----------------------+
# |    1|               0.0059|             0.0135|                 2.8E-5|               0.0117|             0.0267|                 5.6E-5|
# |    0|               0.0013|             0.0041|                 7.0E-6|               0.0027|             0.0086|                 1.5E-5|
# +-----+---------------------+-------------------+-----------------------+---------------------+-------------------+-----------------------+

# %%
#avg song length and songs played hour explore
spark.sql("select churn, \
           avg(length) avg_song_length, \
           avg(hour) avg_hour_per_day \
           from df_valid \
           where page='NextSong' \
           group by churn \
          ").show()
#no big difference
# Out:
# +-----+------------------+------------------+
# |churn|   avg_song_length|  avg_hour_per_day|
# +-----+------------------+------------------+
# |    1|248.63279564406218|12.318129361982745|
# |    0|249.20913538880816|12.169346004986595|
# +-----+------------------+------------------+

# %%
#One day might contain multiple sessions
spark.sql("select userid,date,count(distinct sessionId) session \
           from df_valid \
           group by userid,date \
           having count(distinct sessionId) >1 \
           order by 2 desc \
          ").show()
# Out:
# +------+----------+-------+
# |userid|      date|session|
# +------+----------+-------+
# |    85|2018-11-30|      2|
# |   112|2018-11-30|      2|
# |300018|2018-11-30|      2|
# |   140|2018-11-30|      2|
# |    39|2018-11-30|      2|
# |    92|2018-11-30|      3|
# |200023|2018-11-30|      2|
# |300021|2018-11-30|      2|
# |300011|2018-11-30|      3|
# |300025|2018-11-29|      2|
# |    92|2018-11-29|      4|
# |200003|2018-11-29|      3|
# |    85|2018-11-29|      2|
# |    39|2018-11-29|      2|
# |300017|2018-11-29|      2|
# |   136|2018-11-29|      2|
# |300015|2018-11-29|      2|
# |    25|2018-11-28|      2|
# |    82|2018-11-28|      2|
# |100004|2018-11-28|      2|
# +------+----------+-------+
# only showing top 20 rows

# %%
#check top user
df_valid.filter((df_valid.userId=='85') & (df_valid.date == '2018-11-30')).sort("ts").collect()
# Out:
# [Row(artist='Eddie Izzard', auth='Logged In', firstName='Brayden', gender='M', itemInSession=32, lastName='Thomas', length=606.74567, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Horror Movies', status=200, ts=1543536082000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='Leon Russell', auth='Logged In', firstName='Brayden', gender='M', itemInSession=33, lastName='Thomas', length=185.73016, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Act Naturally (Album Version)', status=200, ts=1543536688000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='Wilson Simonal', auth='Logged In', firstName='Brayden', gender='M', itemInSession=34, lastName='Thomas', length=201.11628, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='SÃ\x83Â¡ Marina (1994 Digital Remaster)', status=200, ts=1543536873000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='Mike Koglin', auth='Logged In', firstName='Brayden', gender='M', itemInSession=35, lastName='Thomas', length=475.32363, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='The Silence', status=200, ts=1543537074000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=36, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='About', registration=1534133898000, sessionId=2431, song=None, status=200, ts=1543537083000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='BjÃ\x83Â¶rk', auth='Logged In', firstName='Brayden', gender='M', itemInSession=37, lastName='Thomas', length=348.57751, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Undo', status=200, ts=1543537549000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='Kings Of Leon', auth='Logged In', firstName='Brayden', gender='M', itemInSession=38, lastName='Thomas', length=231.81016, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Use Somebody', status=200, ts=1543537897000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='Samajona', auth='Logged In', firstName='Brayden', gender='M', itemInSession=39, lastName='Thomas', length=185.88689, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Warum?!', status=200, ts=1543538128000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='Base Ball Bear', auth='Logged In', firstName='Brayden', gender='M', itemInSession=40, lastName='Thomas', length=255.60771, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Sayonara-Nostalgia', status=200, ts=1543538313000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='Sleater-kinney', auth='Logged In', firstName='Brayden', gender='M', itemInSession=41, lastName='Thomas', length=264.4371, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Jumpers (Album)', status=200, ts=1543538568000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='Josh Turner', auth='Logged In', firstName='Brayden', gender='M', itemInSession=42, lastName='Thomas', length=192.31302, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song="Why Don't We Just Dance", status=200, ts=1543538832000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=43, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Settings', registration=1534133898000, sessionId=2431, song=None, status=200, ts=1543538874000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Crystal Method', auth='Logged In', firstName='Brayden', gender='M', itemInSession=44, lastName='Thomas', length=304.29995, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song="Comin' Back", status=200, ts=1543539024000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='Yung Joc', auth='Logged In', firstName='Brayden', gender='M', itemInSession=45, lastName='Thomas', length=265.97832, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Knock It Out [Explicit Album Version]', status=200, ts=1543539328000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='Citizen Cope featuring Carlos Santana', auth='Logged In', firstName='Brayden', gender='M', itemInSession=46, lastName='Thomas', length=244.11383, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song="Son's Gonna Rise", status=200, ts=1543539593000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='0', date=datetime.date(2018, 11, 30)),
#  Row(artist='Bacilos', auth='Logged In', firstName='Brayden', gender='M', itemInSession=47, lastName='Thomas', length=237.42649, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Mi primer millon', status=200, ts=1543539837000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Shawnna / Buddy Guy / Shareefa', auth='Logged In', firstName='Brayden', gender='M', itemInSession=48, lastName='Thomas', length=252.57751, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song="Can't Break Me", status=200, ts=1543540074000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Runaways', auth='Logged In', firstName='Brayden', gender='M', itemInSession=49, lastName='Thomas', length=271.09832, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Born To Be Bad', status=200, ts=1543540326000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Red Hot Chili Peppers', auth='Logged In', firstName='Brayden', gender='M', itemInSession=50, lastName='Thomas', length=273.94567, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Shallow Be Thy Game (Album Version)', status=200, ts=1543540597000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Horkyze Slyze', auth='Logged In', firstName='Brayden', gender='M', itemInSession=51, lastName='Thomas', length=124.44689, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Fakty', status=200, ts=1543540870000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Krizz Kaliko featuring Tech N9ne', auth='Logged In', firstName='Brayden', gender='M', itemInSession=52, lastName='Thomas', length=190.22322, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='So High', status=200, ts=1543540994000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Lil Boosie feat. Webbie', auth='Logged In', firstName='Brayden', gender='M', itemInSession=53, lastName='Thomas', length=276.08771, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Smoking On Purple (feat. Webbie) (amended album version)', status=200, ts=1543541184000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Mogwai', auth='Logged In', firstName='Brayden', gender='M', itemInSession=54, lastName='Thomas', length=482.76853, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song="You Don'T Know Jesus", status=200, ts=1543541460000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Wolfmother', auth='Logged In', firstName='Brayden', gender='M', itemInSession=55, lastName='Thomas', length=227.65669, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Sundial', status=200, ts=1543541942000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Cartola', auth='Logged In', firstName='Brayden', gender='M', itemInSession=56, lastName='Thomas', length=127.242, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Tive Sim', status=200, ts=1543542169000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Catupecu Machu', auth='Logged In', firstName='Brayden', gender='M', itemInSession=57, lastName='Thomas', length=267.54567, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Puedes', status=200, ts=1543542296000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Bon Iver', auth='Logged In', firstName='Brayden', gender='M', itemInSession=58, lastName='Thomas', length=238.49751, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Skinny Love', status=200, ts=1543542563000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=59, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Thumbs Up', registration=1534133898000, sessionId=2431, song=None, status=307, ts=1543542564000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='MIKA', auth='Logged In', firstName='Brayden', gender='M', itemInSession=60, lastName='Thomas', length=188.08118, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Grace Kelly', status=200, ts=1543542801000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Hot Water Music', auth='Logged In', firstName='Brayden', gender='M', itemInSession=61, lastName='Thomas', length=169.50812, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Trusty Chords', status=200, ts=1543542989000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='Radiohead', auth='Logged In', firstName='Brayden', gender='M', itemInSession=62, lastName='Thomas', length=235.7024, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Creep (Explicit)', status=200, ts=1543543158000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='1', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Flirts', auth='Logged In', firstName='Brayden', gender='M', itemInSession=63, lastName='Thomas', length=540.60363, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Passion', status=200, ts=1543543393000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='2', date=datetime.date(2018, 11, 30)),
#  Row(artist='Beirut', auth='Logged In', firstName='Brayden', gender='M', itemInSession=64, lastName='Thomas', length=211.46077, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Guyamas Sonora', status=200, ts=1543543933000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='2', date=datetime.date(2018, 11, 30)),
#  Row(artist='Steely Dan', auth='Logged In', firstName='Brayden', gender='M', itemInSession=65, lastName='Thomas', length=457.89995, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Deacon Blues', status=200, ts=1543544144000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='2', date=datetime.date(2018, 11, 30)),
#  Row(artist='John Powell', auth='Logged In', firstName='Brayden', gender='M', itemInSession=66, lastName='Thomas', length=125.02159, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Attack From Below The Ice', status=200, ts=1543544601000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='2', date=datetime.date(2018, 11, 30)),
#  Row(artist='Maroon 5', auth='Logged In', firstName='Brayden', gender='M', itemInSession=67, lastName='Thomas', length=195.36934, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song="Until You're Over Me", status=200, ts=1543544726000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='2', date=datetime.date(2018, 11, 30)),
#  Row(artist='Jedi Mind Tricks', auth='Logged In', firstName='Brayden', gender='M', itemInSession=68, lastName='Thomas', length=1059.81342, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Before The Great Collapse', status=200, ts=1543544921000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='2', date=datetime.date(2018, 11, 30)),
#  Row(artist='Ashanti', auth='Logged In', firstName='Brayden', gender='M', itemInSession=69, lastName='Thomas', length=282.46159, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='VooDoo', status=200, ts=1543545980000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='2', date=datetime.date(2018, 11, 30)),
#  Row(artist='Static-X', auth='Logged In', firstName='Brayden', gender='M', itemInSession=70, lastName='Thomas', length=266.47465, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='The Trance Is The Motion [Live]', status=200, ts=1543546262000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='2', date=datetime.date(2018, 11, 30)),
#  Row(artist='Patrice Rushen', auth='Logged In', firstName='Brayden', gender='M', itemInSession=71, lastName='Thomas', length=437.49832, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Forget Me Nots (12" Version)', status=200, ts=1543546528000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='2', date=datetime.date(2018, 11, 30)),
#  Row(artist='Rick Ross', auth='Logged In', firstName='Brayden', gender='M', itemInSession=72, lastName='Thomas', length=256.44363, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Mafia Music', status=200, ts=1543546965000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=73, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Help', registration=1534133898000, sessionId=2431, song=None, status=200, ts=1543547044000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Aerosmith', auth='Logged In', firstName='Brayden', gender='M', itemInSession=74, lastName='Thomas', length=267.33669, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Dream On', status=200, ts=1543547221000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Jay-Z', auth='Logged In', firstName='Brayden', gender='M', itemInSession=75, lastName='Thomas', length=212.27057, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song="D'Evils", status=200, ts=1543547488000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=76, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Add to Playlist', registration=1534133898000, sessionId=2431, song=None, status=200, ts=1543547527000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Sanctus Real', auth='Logged In', firstName='Brayden', gender='M', itemInSession=77, lastName='Thomas', length=197.27628, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song="I'll Show You How To Live", status=200, ts=1543547700000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Anthony David', auth='Logged In', firstName='Brayden', gender='M', itemInSession=78, lastName='Thomas', length=242.442, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Words (feat India.Arie)', status=200, ts=1543547897000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Cartola', auth='Logged In', firstName='Brayden', gender='M', itemInSession=79, lastName='Thomas', length=127.242, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Tive Sim', status=200, ts=1543548139000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Feist', auth='Logged In', firstName='Brayden', gender='M', itemInSession=80, lastName='Thomas', length=175.43791, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Let It Die', status=200, ts=1543548266000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Lily Allen', auth='Logged In', firstName='Brayden', gender='M', itemInSession=81, lastName='Thomas', length=201.1424, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Not Fair (Clean Radio Edit)', status=200, ts=1543548441000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=82, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Thumbs Up', registration=1534133898000, sessionId=2431, song=None, status=307, ts=1543548442000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Postal Service', auth='Logged In', firstName='Brayden', gender='M', itemInSession=83, lastName='Thomas', length=226.61179, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Nothing Better (Album)', status=200, ts=1543548642000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Florence + The Machine', auth='Logged In', firstName='Brayden', gender='M', itemInSession=84, lastName='Thomas', length=219.66322, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Dog Days Are Over (Radio Edit)', status=200, ts=1543548868000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Black Keys', auth='Logged In', firstName='Brayden', gender='M', itemInSession=85, lastName='Thomas', length=191.76444, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Howlin\x19 For You', status=200, ts=1543549087000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Weepies', auth='Logged In', firstName='Brayden', gender='M', itemInSession=86, lastName='Thomas', length=197.92934, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Gotta Have You', status=200, ts=1543549278000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Jason Mraz', auth='Logged In', firstName='Brayden', gender='M', itemInSession=87, lastName='Thomas', length=226.53342, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='After An Afternoon (Eagles Ballroom Live Version)', status=200, ts=1543549475000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Barry White', auth='Logged In', firstName='Brayden', gender='M', itemInSession=88, lastName='Thomas', length=307.9571, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song="Honey Please_ Can't Ya See", status=200, ts=1543549701000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=89, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Home', registration=1534133898000, sessionId=2431, song=None, status=200, ts=1543549929000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=90, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Add Friend', registration=1534133898000, sessionId=2431, song=None, status=307, ts=1543549930000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Metallica', auth='Logged In', firstName='Brayden', gender='M', itemInSession=91, lastName='Thomas', length=541.67465, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Bleeding Me', status=200, ts=1543550008000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='3', date=datetime.date(2018, 11, 30)),
#  Row(artist='Mayday Parade', auth='Logged In', firstName='Brayden', gender='M', itemInSession=92, lastName='Thomas', length=209.8673, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Walk On Water Or Drown (Album)', status=200, ts=1543550549000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist='Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', auth='Logged In', firstName='Brayden', gender='M', itemInSession=93, lastName='Thomas', length=277.15873, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', status=200, ts=1543550758000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Killers', auth='Logged In', firstName='Brayden', gender='M', itemInSession=94, lastName='Thomas', length=220.89098, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='When You Were Young', status=200, ts=1543551035000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist='Moby', auth='Logged In', firstName='Brayden', gender='M', itemInSession=95, lastName='Thomas', length=228.25751, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='South Side', status=200, ts=1543551255000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist='Beirut', auth='Logged In', firstName='Brayden', gender='M', itemInSession=96, lastName='Thomas', length=206.57587, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='The Concubine', status=200, ts=1543551483000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=97, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Thumbs Down', registration=1534133898000, sessionId=2431, song=None, status=307, ts=1543551484000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist='Beng Beng Cocktail', auth='Logged In', firstName='Brayden', gender='M', itemInSession=98, lastName='Thomas', length=177.94567, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='I say love', status=200, ts=1543551689000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist='Ramsey Lewis', auth='Logged In', firstName='Brayden', gender='M', itemInSession=99, lastName='Thomas', length=316.05506, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Julia', status=200, ts=1543551866000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=100, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Thumbs Up', registration=1534133898000, sessionId=2431, song=None, status=307, ts=1543551867000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Specials', auth='Logged In', firstName='Brayden', gender='M', itemInSession=101, lastName='Thomas', length=182.5171, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Concrete Jungle (BBC In Concert)', status=200, ts=1543552182000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Hold Steady', auth='Logged In', firstName='Brayden', gender='M', itemInSession=102, lastName='Thomas', length=216.52853, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Yeah Sapphire', status=200, ts=1543552364000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=103, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Thumbs Down', registration=1534133898000, sessionId=2431, song=None, status=307, ts=1543552365000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist='Florence + The Machine', auth='Logged In', firstName='Brayden', gender='M', itemInSession=104, lastName='Thomas', length=176.69179, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='My Boy Builds Coffins', status=200, ts=1543552580000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Killers', auth='Logged In', firstName='Brayden', gender='M', itemInSession=105, lastName='Thomas', length=206.10567, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song="Why Don't You Find Out For Yourself", status=200, ts=1543552756000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=106, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Downgrade', registration=1534133898000, sessionId=2431, song=None, status=200, ts=1543552798000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=107, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Logout', registration=1534133898000, sessionId=2431, song=None, status=307, ts=1543552799000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=112, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Home', registration=1534133898000, sessionId=2431, song=None, status=200, ts=1543553216000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist='Justin Bieber', auth='Logged In', firstName='Brayden', gender='M', itemInSession=113, lastName='Thomas', length=220.89098, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2431, song='Somebody To Love', status=200, ts=1543553344000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=114, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Downgrade', registration=1534133898000, sessionId=2431, song=None, status=200, ts=1543553466000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=115, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Downgrade', registration=1534133898000, sessionId=2431, song=None, status=200, ts=1543553525000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=116, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Logout', registration=1534133898000, sessionId=2431, song=None, status=307, ts=1543553526000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='4', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=2, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Home', registration=1534133898000, sessionId=2444, song=None, status=200, ts=1543576813000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='11', date=datetime.date(2018, 11, 30)),
#  Row(artist='1200 Micrograms', auth='Logged In', firstName='Brayden', gender='M', itemInSession=3, lastName='Thomas', length=391.44444, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Salvia Divinorum', status=200, ts=1543576876000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='11', date=datetime.date(2018, 11, 30)),
# ...
#  Row(artist='The Kooks', auth='Logged In', firstName='Brayden', gender='M', itemInSession=112, lastName='Thomas', length=159.76444, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Always Where I Need To Be', status=200, ts=1543599359000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='17', date=datetime.date(2018, 11, 30)),
#  Row(artist='Spice Girls', auth='Logged In', firstName='Brayden', gender='M', itemInSession=113, lastName='Thomas', length=271.59465, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Too Much', status=200, ts=1543599518000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='17', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=114, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Home', registration=1534133898000, sessionId=2444, song=None, status=200, ts=1543599523000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='17', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Wallflowers', auth='Logged In', firstName='Brayden', gender='M', itemInSession=115, lastName='Thomas', length=312.63302, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='One Headlight', status=200, ts=1543599789000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='17', date=datetime.date(2018, 11, 30)),
#  Row(artist='Foo Fighters', auth='Logged In', firstName='Brayden', gender='M', itemInSession=116, lastName='Thomas', length=309.28934, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Band On The Run', status=200, ts=1543600101000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='17', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Decemberists', auth='Logged In', firstName='Brayden', gender='M', itemInSession=117, lastName='Thomas', length=320.33914, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Odalisque', status=200, ts=1543600410000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='17', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=118, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Thumbs Up', registration=1534133898000, sessionId=2444, song=None, status=307, ts=1543600411000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='17', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=119, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Add to Playlist', registration=1534133898000, sessionId=2444, song=None, status=200, ts=1543600414000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='17', date=datetime.date(2018, 11, 30)),
#  Row(artist='Paolo Conte', auth='Logged In', firstName='Brayden', gender='M', itemInSession=120, lastName='Thomas', length=234.84036, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='La petite tendresse', status=200, ts=1543600730000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='17', date=datetime.date(2018, 11, 30)),
#  Row(artist='Lynyrd Skynyrd', auth='Logged In', firstName='Brayden', gender='M', itemInSession=121, lastName='Thomas', length=216.60689, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Sweet home Alabama', status=200, ts=1543600964000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='Florence + The Machine', auth='Logged In', firstName='Brayden', gender='M', itemInSession=122, lastName='Thomas', length=219.66322, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Dog Days Are Over (Radio Edit)', status=200, ts=1543601180000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='Laura Pausini', auth='Logged In', firstName='Brayden', gender='M', itemInSession=123, lastName='Thomas', length=273.60608, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Gente', status=200, ts=1543601399000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=124, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Home', registration=1534133898000, sessionId=2444, song=None, status=200, ts=1543601492000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=125, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Home', registration=1534133898000, sessionId=2444, song=None, status=200, ts=1543601512000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='Okkervil River', auth='Logged In', firstName='Brayden', gender='M', itemInSession=126, lastName='Thomas', length=156.78649, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Dead Faces', status=200, ts=1543601672000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='Boom Bip & Doseone', auth='Logged In', firstName='Brayden', gender='M', itemInSession=127, lastName='Thomas', length=197.48526, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Slight', status=200, ts=1543601828000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='The All-American Rejects', auth='Logged In', firstName='Brayden', gender='M', itemInSession=128, lastName='Thomas', length=213.08036, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Gives You Hell', status=200, ts=1543602025000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='Kid Cudi / Kanye West / Common', auth='Logged In', firstName='Brayden', gender='M', itemInSession=129, lastName='Thomas', length=237.76608, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Make Her Say', status=200, ts=1543602238000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='In Flames', auth='Logged In', firstName='Brayden', gender='M', itemInSession=130, lastName='Thomas', length=170.4224, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Clad In Shadows', status=200, ts=1543602475000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='The Dodos', auth='Logged In', firstName='Brayden', gender='M', itemInSession=131, lastName='Thomas', length=128.83546, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Walking', status=200, ts=1543602645000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='Radiohead', auth='Logged In', firstName='Brayden', gender='M', itemInSession=132, lastName='Thomas', length=231.91465, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='(Nice Dream)', status=200, ts=1543602773000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='Chase & Status', auth='Logged In', firstName='Brayden', gender='M', itemInSession=133, lastName='Thomas', length=198.39955, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='End Credits', status=200, ts=1543603004000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=134, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='Add to Playlist', registration=1534133898000, sessionId=2444, song=None, status=200, ts=1543603083000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='Wykked Wytch', auth='Logged In', firstName='Brayden', gender='M', itemInSession=135, lastName='Thomas', length=224.31302, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Ripping Flesh', status=200, ts=1543603202000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='Eric Burdon & War', auth='Logged In', firstName='Brayden', gender='M', itemInSession=136, lastName='Thomas', length=281.93914, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Jimbo (Album Version)', status=200, ts=1543603426000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist='Kings Of Leon', auth='Logged In', firstName='Brayden', gender='M', itemInSession=137, lastName='Thomas', length=231.81016, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='PUT', page='NextSong', registration=1534133898000, sessionId=2444, song='Use Somebody', status=200, ts=1543603707000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30)),
#  Row(artist=None, auth='Logged In', firstName='Brayden', gender='M', itemInSession=138, lastName='Thomas', length=None, level='paid', location='Los Angeles-Long Beach-Anaheim, CA', method='GET', page='Downgrade', registration=1534133898000, sessionId=2444, song=None, status=200, ts=1543603730000, userAgent='"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"', userId='85', Cancellation=0, Churn=0, year='2018', month='11', day='30', hour='18', date=datetime.date(2018, 11, 30))]

# %%
#distinct sessions, item in sessions, page per user example
spark.sql("select churn, count(distinct sessionid)/count(distinct userid) sessions_per_user \
          ,count(distinct itemInSession)/count(distinct userid) items_per_user \
          ,count(distinct page)/count(distinct userid) pages_per_user\
          ,count(distinct itemInSession)/count(distinct sessionid) items_per_session \
          ,count(distinct page)/count(distinct sessionid) pages_per_session \
          from df_valid \
          where userid ='85' and date ='2018-11-30' \
          group by churn \
          ").show()
# Out:
# +-----+-----------------+--------------+--------------+-----------------+-----------------+
# |churn|sessions_per_user|items_per_user|pages_per_user|items_per_session|pages_per_session|
# +-----+-----------------+--------------+--------------+-----------------+-----------------+
# |    0|              2.0|         137.0|          11.0|             68.5|              5.5|
# +-----+-----------------+--------------+--------------+-----------------+-----------------+

# %%
#distinct sessions, item in sessions, page per user
spark.sql("select churn, count(distinct sessionid)/count(distinct userid) sessions_per_user \
          ,count(distinct itemInSession)/count(distinct userid) items_per_user \
          ,count(distinct page)/count(distinct userid) pages_per_user\
          ,count(distinct itemInSession)/count(distinct sessionid) items_per_session \
          ,count(distinct page)/count(distinct sessionid) pages_per_session \
          from df_valid \
          where Cancellation=0 \
          group by churn \
          ").show()
#Users who churned have fewer average sessions, more items in sessions and more distinct pages \
#(exclude Cancellation)
# Out:
# +-----+------------------+-----------------+-------------------+------------------+--------------------+
# |churn| sessions_per_user|   items_per_user|     pages_per_user| items_per_session|   pages_per_session|
# +-----+------------------+-----------------+-------------------+------------------+--------------------+
# |    1|               9.0|17.03846153846154|0.34615384615384615| 1.893162393162393|0.038461538461538464|
# |    0|12.196531791907514|7.578034682080925|0.09826589595375723|0.6213270142180095|0.008056872037914692|
# +-----+------------------+-----------------+-------------------+------------------+--------------------+

# %%
#distinct sessions, item in sessions, page per user per day
spark.sql("select churn, avg(sessions) avg_sessions,avg(items) avg_items,avg(pages) avg_pages \
          from (select churn,userid,date, count(distinct sessionid) sessions \
          ,count(itemInSession) items \
          ,count(distinct page) pages\
          from df_valid \
          where Cancellation=0 \
          group by churn,userid,date ) a\
          group by churn \
          ").show()
#Users who churned have similar average sessions, fewer items in sessions and more distinct pages per day \
#(exclude Cancellation)
# Out:
# +-----+------------------+-----------------+-----------------+
# |churn|      avg_sessions|        avg_items|        avg_pages|
# +-----+------------------+-----------------+-----------------+
# |    1|1.2627450980392156|87.86666666666666|6.974509803921569|
# |    0|1.2139303482587065|89.28052047455033|6.571373899732109|
# +-----+------------------+-----------------+-----------------+

# %% [markdown]
# # Feature Engineering
# Build out those 18 features on the small dataset first and then transfer over the features to the larger dataset on Spark cluster.

# %% [markdown]
# ### Extract Potential Features
# - gender: female(1) or male(0)
# - main state ratio: State with highest frequency / Count of total states
# - distinct locations: Count of distinct locations
# - distinct page actions: Count of distinct pages
# - page action ratios
#     - tbup_ratio: Count of Thumbs Up events / Count of total pages
#     - tbdw_ratio: Count of Thumbs Down events / Count of total pages
#     - addfriend_ratio: Count of Add Friend events / Count of total pages
#     - ad_ratio: Count of Roll Advert events / Count of total pages
#     - up_ratio: Count of Upgrade events / Count of total pages
#     - help_ratio: Count of Help events / Count of total pages
#     - error_ratio: Count of Error events / Count of total pages
#
# - enroll days: max date - min date +1
# - active days: Count of distinct dates
# - active ratio: active days / enroll days
# - distinct artists per active day: Count of distinct artists / active days
# - distinct songs per active day: Count of distinct songs / active days
# - avg songs per active day: Count of total songs / active days
# - avg items per session: Count of total items / Count of distinct sessions

# %%
# main state (highest frequency)
df_valid = df_valid.withColumn("state", trim(element_at(split(col("location"), ","),-1)))
state_cnt = df_valid.groupBy("userId", "state").count()

w = Window().partitionBy("userId").orderBy(col("count").desc())

main_state = (state_cnt
  .withColumn("rn", row_number().over(w))
  .where(col("rn") == 1)
  .select("userId", col("state").alias('main_state')))

# %%
# Adding main state feature to df_valid
df_valid = df_valid.join(main_state, on = 'userId')

# %%
#check state values
df_valid.groupby('main_state').agg(countDistinct(col('userid')).alias('ct')).sort(desc('ct')).show()
# Out:
# +-----------+---+
# | main_state| ct|
# +-----------+---+
# |         CA| 33|
# |         TX| 16|
# |   NY-NJ-PA| 15|
# |         FL| 14|
# |         CT|  7|
# |         AZ|  7|
# |   IL-IN-WI|  6|
# |      MO-IL|  6|
# |         NC|  6|
# |      NC-SC|  6|
# |PA-NJ-DE-MD|  5|
# |      MA-NH|  5|
# |         NY|  5|
# |         MI|  5|
# |         GA|  4|
# |         WA|  4|
# |         CO|  4|
# |DC-VA-MD-WV|  4|
# |         AL|  4|
# |         IL|  3|
# +-----------+---+
# only showing top 20 rows

# %%
# Extract potential features 
df_user = df_valid.groupby('userId').agg(
     # target
     first(col('Churn')).alias('label'),
     # gender
     first(when(col('gender') == "F", 1).otherwise(0)).alias('female'),
     # #main state ratio
     ((sum(when(col('state') == col('main_state'), 1).otherwise(0)))/count(col('state'))).alias("mstate_ratio"),
     # distinct locations
     countDistinct(col('location')).alias('ulocation_ct'),
     # distinct page actions
     countDistinct(col('page')).alias('upage_ct'),
     # page action ratio
    ((sum(when(col('page') == "Thumbs Up", 1).otherwise(0)))/count(col('page'))).alias("tbup_ratio"),
    ((sum(when(col('page') == "Thumbs Down", 1).otherwise(0)))/count(col('page'))).alias("tbdw_ratio"),
    ((sum(when(col('page') == "Add Friend", 1).otherwise(0)))/count(col('page'))).alias("addfriend_ratio"),   
    ((sum(when(col('page') == "Roll Advert", 1).otherwise(0)))/count(col('page'))).alias("ad_ratio"),
    ((sum(when(col('page') == "Upgrade", 1).otherwise(0)))/count(col('page'))).alias("up_ratio"),
    ((sum(when(col('page') == "Help", 1).otherwise(0)))/count(col('page'))).alias("help_ratio"),
    ((sum(when(col('page') == "Error", 1).otherwise(0)))/count(col('page'))).alias("error_ratio"),
     # enroll days
     (datediff(max(col('date')),min(col('date'))) +1).alias("enroll_days"),
     # active days
     countDistinct(col('date')).alias('active_days'),
     # active ratio
     (countDistinct(col('date'))/(datediff(max(col('date')),min(col('date'))) +1)).alias('active_ratio'),
     # distinct artists per active day 
     (countDistinct(col('artist'))/countDistinct(col('date'))).alias('uartist_pact'),
     # distinct songs per active day
     (countDistinct(col('song'))/countDistinct(col('date'))).alias('usong_pact'),
     # avg songs per active day 
     (sum(when(col('page') == "NextSong",1).otherwise(0))/countDistinct(col('date'))).alias("tsong_pact"),
     # avg items per session
     (count(col('itemInSession'))/countDistinct(col('sessionId'))).alias("item_pses"))

# %%
#check user example
df_valid.groupby('userId').count().sort("count").head(5)
# Out:
# [Row(userId='156', count=6),
#  Row(userId='135', count=6),
#  Row(userId='125', count=11),
#  Row(userId='100011', count=23),
#  Row(userId='300003', count=35)]

# %%
#check user example
#df_valid.filter(df_valid.userId=='156').collect()

# %%
#check user example
df_user.filter(df_user.userId=='156').collect()
# Out:
# [Row(userId='156', label=0, female=0, mstate_ratio=1.0, ulocation_ct=1, upage_ct=4, tbup_ratio=0.0, tbdw_ratio=0.0, addfriend_ratio=0.0, ad_ratio=0.16666666666666666, up_ratio=0.0, help_ratio=0.0, error_ratio=0.0, enroll_days=1, active_days=1, active_ratio=1.0, uartist_pact=3.0, usong_pact=3.0, tsong_pact=3.0, item_pses=6.0)]

# %% [markdown]
# ### Features Visualization
# Then create some visualization on those new features.

# %%
#convert a Spark Df to pandas DF
pandas_df = df_user.toPandas()

# %%
#check data size
pandas_df.shape
# Out:
# (225, 20)

# %% [markdown]
# #### Target measure

# %%
#target measure counts
pandas_df.label.value_counts()
# Out:
# 0    173
# 1     52
# Name: label, dtype: int64

# %%
#target measure plots
plt.figure(figsize = (8,5));
pandas_df.label.value_counts(normalize =True).plot(kind ='bar')
plt.ylabel('Percent');
plt.title('Churn Distribution');
plt.savefig('churn.png')

# %% [markdown]
# #### Independent Variables

# %% [markdown]
# ##### Categorical Variables

# %%
# gender
pandas_df.female = pandas_df.female.astype('category')

# %%
# female have lower churned rate
pandas_df.groupby('label').female.value_counts(normalize =True)
# Out:
# label  female
# 0      0         0.514451
#        1         0.485549
# 1      0         0.615385
#        1         0.384615
# Name: female, dtype: float64

# %%
# count plot for gender
plt.figure(figsize = (8,5));
sns.countplot(x='female',hue ='label',data = pandas_df);
plt.legend(['Not Churned', 'Churned']);
plt.title('Female');
plt.xlabel("");
plt.savefig('images/gender.png')

# %% [markdown]
# ##### Numeric Variables

# %%
# histogram
pandas_df.hist(figsize = (20,20));

# %%
# correlation map
corr = pandas_df.drop('female',axis =1).corr()
plt.figure(figsize = (14,10))
sns.heatmap(corr, cmap ='YlGnBu',center =0, linewidth =1, annot =True, fmt = '.2f');
plt.show()

# %%
# Two variables have only one value, uartist_pact, usong_pact, tsong_pact, item_pses are highly correlated.
print(pandas_df.mstate_ratio.value_counts())
print(pandas_df.ulocation_ct.value_counts())
# Out:
# 1.0    225
# Name: mstate_ratio, dtype: int64
# 1    225
# Name: ulocation_ct, dtype: int64
# ['mstate_ratio', 'ulocation_ct']

# %%
#check unique values
pandas_df.nunique()
# Out:
# userId             225
# label                2
# female               2
# mstate_ratio         1
# ulocation_ct         1
# upage_ct            17
# tbup_ratio         212
# tbdw_ratio         202
# addfriend_ratio    202
# ad_ratio           204
# up_ratio           166
# help_ratio         191
# error_ratio        116
# enroll_days         49
# active_days         42
# active_ratio       166
# uartist_pact       216
# usong_pact         220
# tsong_pact         218
# item_pses          214
# dtype: int64

# %%
#create drop list
one_value_to_drop = pandas_df.columns[pandas_df.nunique()==1].tolist()
one_value_to_drop
# Out:
# ['mstate_ratio', 'ulocation_ct']

# %%
#drop two features
corr = pandas_df.drop(['female']+one_value_to_drop,axis =1).corr()
plt.figure(figsize = (14,10))
sns.heatmap(corr, cmap ='YlGnBu',center =0, linewidth =1, annot =True, fmt = '.2f');
#plt.show()
plt.savefig('images/corr_map.png');

# %%
# Creating ABS correlation matrix
corr_abs = corr.abs()
# Selecting upper triangle of correlation matrix
upper_tri = corr_abs.where(np.triu(np.ones(corr_abs.shape),k=1).astype(np.bool))
# Finding feature columns with correlation greater than 0.95
high_cor_to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
high_cor_to_drop
# Out:
# ['usong_pact', 'tsong_pact']

# %%
#high_cor_to_drop = ['usong_pact', 'tsong_pact']

# %%
#pair plots for highly correlated features
sns.pairplot(pandas_df[['label','uartist_pact', 'usong_pact', 'tsong_pact', 'item_pses']],hue ='label');

# %%
#create density plot function
def density_plot(df,var):
    '''
    INPUT:
    df - pandas dataframe with user data
    var - variable that needs to plot
    
    OUTPUT:
    density plot
    '''
    sns.distplot(df[df['label'] == 0][var], hist = False,  
                kde_kws = {'shade': True},color = 'navy');
    sns.distplot(df[df['label'] == 1][var], hist = False,  
                 kde_kws = {'shade': True}, color = 'orange');
    plt.legend(['Not Churned','Churned']);
    plt.title(var);
    plt.xlabel("");

# %%
#create density plots
num_col = list(set(pandas_df.columns)-set(['userId','label','female','mstate_ratio','ulocation_ct']))

plt.rcParams['figure.figsize'] = (12,15)
for i in range(len(num_col)):
    plt.subplot(5,3,i+1);
    plt.tight_layout();
    density_plot(pandas_df,num_col[i]);
plt.savefig('images/density_plots.png')

# %%
# Droping Marked Features from one value/high correlated
print(one_value_to_drop)
print(high_cor_to_drop)
pandas_df_clean = pandas_df.drop(one_value_to_drop+high_cor_to_drop, axis=1)
# Out:
# ['mstate_ratio', 'ulocation_ct']
# ['usong_pact', 'tsong_pact']

# %%
#check panda data frame
pandas_df_clean.head()
# Out:
#    userId  label female  upage_ct  tbup_ratio  tbdw_ratio  addfriend_ratio  \
# 0  100010      0      1        11    0.044619    0.013123         0.010499
# 1  200002      0      0        14    0.044304    0.012658         0.008439
# 2     125      1      0         4    0.000000    0.000000         0.000000
# 3     124      0      1        14    0.035440    0.008497         0.015337
# 4      51      1      0        15    0.040584    0.008523         0.011364
#
#    ad_ratio  up_ratio  help_ratio  error_ratio  enroll_days  active_days  \
# 0  0.136483  0.005249    0.005249     0.000000           45            7
# 1  0.014768  0.004219    0.004219     0.000000           46            7
# 2  0.090909  0.000000    0.000000     0.000000            1            1
# 3  0.000829  0.000000    0.004767     0.001244           61           33
# 4  0.000000  0.000000    0.004870     0.000406           17           13
#
#    uartist_pact   item_pses
# 0     36.000000   54.428571
# 1     48.428571   79.000000
# 2      8.000000   11.000000
# 3     67.636364  166.379310
# 4    106.538462  246.400000

# %%
# transfer the drop list to spark data frame
drop_list = one_value_to_drop + high_cor_to_drop
df_user_clean = df_user.select([column for column in df_user.columns if column not in drop_list])

# %%
#check spark data frame
df_user_clean.head()
# Out:
# Row(userId='100010', label=0, female=1, upage_ct=11, tbup_ratio=0.04461942257217848, tbdw_ratio=0.013123359580052493, addfriend_ratio=0.010498687664041995, ad_ratio=0.13648293963254593, up_ratio=0.005249343832020997, help_ratio=0.005249343832020997, error_ratio=0.0, enroll_days=45, active_days=7, active_ratio=0.15555555555555556, uartist_pact=36.0, item_pses=54.42857142857143)

# %% [markdown]
# ##### Another way to create drop fields list (if data is too large to transform to pandas data frame)

# %% [markdown]
# ##### 1. fields with only one distinct value

# %%
# countDistinct value for each column
expr = [countDistinct(c).alias(c) for c in df_user.columns]

# apply those functions
countdf =  df_user.select(*expr)
countdf.show()
# Out:
# +------+-----+------+------------+------------+--------+----------+----------+---------------+--------+--------+----------+-----------+-----------+-----------+------------+------------+----------+----------+---------+
# |userId|label|female|mstate_ratio|ulocation_ct|upage_ct|tbup_ratio|tbdw_ratio|addfriend_ratio|ad_ratio|up_ratio|help_ratio|error_ratio|enroll_days|active_days|active_ratio|uartist_pact|usong_pact|tsong_pact|item_pses|
# +------+-----+------+------------+------------+--------+----------+----------+---------------+--------+--------+----------+-----------+-----------+-----------+------------+------------+----------+----------+---------+
# |   225|    2|     2|           1|           1|      17|       212|       202|            202|     204|     166|       191|        116|         49|         42|         166|         216|       220|       218|      214|
# +------+-----+------+------------+------------+--------+----------+----------+---------------+--------+--------+----------+-----------+-----------+-----------+------------+------------+----------+----------+---------+

# %%
# extract the columns which have just one value
one_value_to_drop2 = [k for k,v in countdf.collect()[0].asDict().items() if v == 1]
df_user.drop(*one_value_to_drop2).head()
# Out:
# Row(userId='100010', label=0, female=1, upage_ct=11, tbup_ratio=0.04461942257217848, tbdw_ratio=0.013123359580052493, addfriend_ratio=0.010498687664041995, ad_ratio=0.13648293963254593, up_ratio=0.005249343832020997, help_ratio=0.005249343832020997, error_ratio=0.0, enroll_days=45, active_days=7, active_ratio=0.15555555555555556, uartist_pact=36.0, usong_pact=38.42857142857143, tsong_pact=39.285714285714285, item_pses=54.42857142857143)

# %% [markdown]
# ##### 2. fields with high correlation

# %%
#numeric variables
num_vector = ['label']+num_col

# %%
# convert to vector column first
vector_col = "corr_features"
assembler = VectorAssembler(inputCols=df_user.select(num_vector).columns, outputCol=vector_col)
df_vector = assembler.transform(df_user.select(num_vector)).select(vector_col)

# get correlation matrix
matrix = Correlation.corr(df_vector, vector_col)

# %%
#matrix head name
head = df_user.select(num_vector).columns

# %%
#correlation matrix
corr2 = pd.DataFrame(matrix.collect()[0]["pearson({})".format(vector_col)].values.reshape(16,16))
corr2.columns = head
corr2.index = head
corr2
# Out:
#                     label  tsong_pact  upage_ct  active_ratio  tbup_ratio  \
# label            1.000000   -0.032635  0.177775      0.306916   -0.082932
# tsong_pact      -0.032635    1.000000  0.551136      0.199857    0.102639
# upage_ct         0.177775    0.551136  1.000000     -0.006650    0.076978
# active_ratio     0.306916    0.199857 -0.006650      1.000000   -0.062612
# tbup_ratio      -0.082932    0.102639  0.076978     -0.062612    1.000000
# uartist_pact     0.012761    0.938745  0.437755      0.139385    0.099859
# item_pses       -0.080740    0.901303  0.421915      0.094206    0.072193
# active_days     -0.201330    0.387916  0.580030      0.276600    0.098693
# error_ratio     -0.071445    0.016017  0.056719     -0.094503   -0.006694
# up_ratio         0.071702   -0.340324 -0.035070     -0.197115   -0.049235
# addfriend_ratio -0.049472   -0.092251 -0.088330     -0.120594    0.071053
# tbdw_ratio       0.271399   -0.039957  0.226958      0.076682   -0.092484
# help_ratio      -0.055849   -0.035317  0.038652     -0.097812   -0.054521
# enroll_days     -0.521747    0.170078  0.435769     -0.474681    0.098787
# ad_ratio         0.179220   -0.619020 -0.481727      0.031481   -0.232461
# usong_pact      -0.017212    0.992862  0.526682      0.175433    0.101683
#
#                  uartist_pact  item_pses  active_days  error_ratio  up_ratio  \
# label                0.012761  -0.080740    -0.201330    -0.071445  0.071702
# tsong_pact           0.938745   0.901303     0.387916     0.016017 -0.340324
# upage_ct             0.437755   0.421915     0.580030     0.056719 -0.035070
# active_ratio         0.139385   0.094206     0.276600    -0.094503 -0.197115
# tbup_ratio           0.099859   0.072193     0.098693    -0.006694 -0.049235
# uartist_pact         1.000000   0.886689     0.103935     0.041809 -0.277875
# item_pses            0.886689   1.000000     0.180457     0.015618 -0.317194
# active_days          0.103935   0.180457     1.000000    -0.025241 -0.211294
# error_ratio          0.041809   0.015618    -0.025241     1.000000  0.074879
# up_ratio            -0.277875  -0.317194    -0.211294     0.074879  1.000000
# addfriend_ratio     -0.067450  -0.069723    -0.109281    -0.046654  0.168265
# tbdw_ratio          -0.030360  -0.052408     0.037820     0.027817  0.085506
# help_ratio          -0.049881  -0.045793     0.008394     0.127748 -0.124293
# enroll_days         -0.013713   0.110556     0.607023     0.056955 -0.070007
# ad_ratio            -0.547193  -0.555209    -0.389628    -0.046148  0.331774
# usong_pact           0.972076   0.911654     0.296809     0.024883 -0.325932
#
#                  addfriend_ratio  tbdw_ratio  help_ratio  enroll_days  \
# label                  -0.049472    0.271399   -0.055849    -0.521747
# tsong_pact             -0.092251   -0.039957   -0.035317     0.170078
# upage_ct               -0.088330    0.226958    0.038652     0.435769
# active_ratio           -0.120594    0.076682   -0.097812    -0.474681
# tbup_ratio              0.071053   -0.092484   -0.054521     0.098787
# uartist_pact           -0.067450   -0.030360   -0.049881    -0.013713
# item_pses              -0.069723   -0.052408   -0.045793     0.110556
# active_days            -0.109281    0.037820    0.008394     0.607023
# error_ratio            -0.046654    0.027817    0.127748     0.056955
# up_ratio                0.168265    0.085506   -0.124293    -0.070007
# addfriend_ratio         1.000000   -0.025391   -0.090711    -0.033553
# tbdw_ratio             -0.025391    1.000000   -0.200463    -0.022796
# help_ratio             -0.090711   -0.200463    1.000000     0.034559
# enroll_days            -0.033553   -0.022796    0.034559     1.000000
# ad_ratio                0.037748    0.110280   -0.067842    -0.335180
# usong_pact             -0.086127   -0.036779   -0.038714     0.116835
#
#                  ad_ratio  usong_pact
# label            0.179220   -0.017212
# tsong_pact      -0.619020    0.992862
# upage_ct        -0.481727    0.526682
# active_ratio     0.031481    0.175433
# tbup_ratio      -0.232461    0.101683
# uartist_pact    -0.547193    0.972076
# item_pses       -0.555209    0.911654
# active_days     -0.389628    0.296809
# error_ratio     -0.046148    0.024883
# up_ratio         0.331774   -0.325932
# addfriend_ratio  0.037748   -0.086127
# tbdw_ratio       0.110280   -0.036779
# help_ratio      -0.067842   -0.038714
# enroll_days     -0.335180    0.116835
# ad_ratio         1.000000   -0.608100
# usong_pact      -0.608100    1.000000

# %%
# Creating ABS correlation matrix
corr_abs2 = corr2.abs()
# Selecting upper triangle of correlation matrix
upper_tri2 = corr_abs2.where(np.triu(np.ones(corr_abs2.shape),k=1).astype(np.bool))
# Finding feature columns with correlation greater than 0.95
high_cor_to_drop2 = [column for column in upper_tri2.columns if any(upper_tri2[column] > 0.95)]
high_cor_to_drop2

#difference due to the order of columns
# Out:
# ['usong_pact']

# %% [markdown]
# # Modelling and Evaluation
# This part contains several steps:
# 1. Split the full dataset into train(cross-validation) and test sets.
# 2. Build machine learning Pipeline and evaluate the test accuracy of several classifiers.
# 3. Conduct 3-fold cross validation and tune parameters.
# 4. Implement three methods to treat imbalanced class issue.
#
# I use the F1 score and accuracy as the performance metrics. F1 score is a better choice for the imbalanced data, especially for small subset of data here.
# - F1 score: The weighted average of Precision and Recall.
# - Accuracy: The measure of all the correctly identified cases.

# %% [markdown]
# ### Step 1. Split the full dataset into train (cross-validation) and test sets.

# %%
#split the data
train, test = df_user_clean.randomSplit([0.7, 0.3], seed=42)

# %% [markdown]
# ### Step 2. Build machine learning Pipeline and evaluate the test accuracy of several classifiers.

# %%
#check column list
train.schema.names
# Out:
# ['userId',
#  'label',
#  'female',
#  'upage_ct',
#  'tbup_ratio',
#  'tbdw_ratio',
#  'addfriend_ratio',
#  'ad_ratio',
#  'up_ratio',
#  'help_ratio',
#  'error_ratio',
#  'enroll_days',
#  'active_days',
#  'active_ratio',
#  'uartist_pact',
#  'item_pses']

# %%
#create initial machine learning pielines
def initial_model(numcols,catcols,classifier = LogisticRegression(maxIter=10),train = train, test = test):
    '''
    INPUT:
    numcols - numerical columns
    catcols - categorical columns (binary)
    classifier - machine learning classifier model
    train - train data
    test - test data
    
    OUTPUT:
    pipeline - machine learning pipeline
    Model - fitted model based on train data
    prediction - predictions on test data
    run time in mins
    '''
    
    start = time.time()
    # Combining into VectorAssembler
    num_assembler = VectorAssembler(inputCols = numcols, outputCol = "num_vector")
    # Standardizing numerical features
    scaler = StandardScaler(inputCol = "num_vector", outputCol = "num_scaled", withStd = True, withMean = True)

    # Add binary feature (do not scale)
    total_assembler = VectorAssembler(inputCols = catcols + ["num_scaled"], outputCol = "features")

    # choose classifiers
    ml =  classifier
    pipeline = Pipeline(stages = [num_assembler, scaler, total_assembler, ml])
    Model = pipeline.fit(train)
    prediction = Model.transform(test) 
    
    end = time.time()
    
    return pipeline,Model, prediction,round(round(end-start)/60,2)

# %%
#evaluation function
def evaluation(prediction):
    '''
    INPUT:
    prediction - predictions on test data
    
    OUTPUT:
    accuracy - metric: (TP + TN)/(TP + TN + FP + FN)
    F1 score - metric: 2 * (Recall * Precision) / (Recall + Precision)
    '''
    
    # Input: model prediction results
    # Output: accuracy and F1 score
       # accuracy: (TP + TN)/(TP + TN + FP + FN)
       # precision: TP/(TP + FP)
       # recall: TP/(TP + FN)
       # f1 score: 2*(Recall * Precision) / (Recall + Precision)
       
    # Combine prediction and labels
    predictionAndLabels = prediction.select(['prediction','label']) \
                      .withColumn("label",col("label").cast(DoubleType())).rdd

    # Instantiate metrics object
    metrics = MulticlassMetrics(predictionAndLabels)
    
    # Overall statistics
    accuracy = metrics.accuracy
    precision = metrics.precision(label =1.0)
    recall = metrics.recall(label =1.0)
    f1Score = metrics.fMeasure(label =1.0)
    print("Summary Stats")
    print("Accuracy = %s" % accuracy)
    print("Precision = %s" % precision)
    print("Recall = %s" % recall)
    print("F1 Score = %s" % f1Score)
       
    return round(accuracy,3),round(f1Score,3)

# %%
#final features used in the model
numcols = ['upage_ct','tbup_ratio','tbdw_ratio','addfriend_ratio','ad_ratio','up_ratio',
           'help_ratio','error_ratio','enroll_days','active_days','active_ratio','uartist_pact','item_pses']
catcols = ['female']

# %% [markdown]
# #### Logistic Regression

# %%
# Create logistic regression classifier
pipeline_lr, model_lr, prediction_lr, time_lr = initial_model(numcols,catcols, \
                                                              LogisticRegression(maxIter=10),train, test)
print('Logistic Regression Run time (mins): ',time_lr)
acc_lr, f1_lr = evaluation(prediction_lr)
# Out:
# Logistic Regression Run time (mins):  1.62
# Summary Stats
# Accuracy = 0.9333333333333333
# Precision = 0.9285714285714286
# Recall = 0.8125
# F1 Score = 0.8666666666666666

# %% [markdown]
# #### Random Forest

# %%
# Create Random Forest classifier 
pipeline_rf, model_rf, prediction_rf, time_rf = initial_model(numcols,catcols, \
                                                              RandomForestClassifier(),train, test)
print('Random Forest Run time (mins): ',time_rf)
acc_rf, f1_rf = evaluation(prediction_rf)
# Out:
# Random Forest Run time (mins):  3.62
# Summary Stats
# Accuracy = 0.8666666666666667
# Precision = 0.9
# Recall = 0.5625
# F1 Score = 0.6923076923076923

# %% [markdown]
# #### Gradient-boosted Tree

# %%
# Create Gradient-boosted tree classifier 
pipeline_gbt, model_gbt, prediction_gbt, time_gbt = initial_model(numcols,catcols, \
                                                                  GBTClassifier(maxIter=10),train, test)
print('Gradient-boosted Tree Run time (mins): ',time_gbt)
acc_gbt, f1_gbt = evaluation(prediction_gbt)
# Out:
# Gradient-boosted Tree Run time (mins):  4.32
# Summary Stats
# Accuracy = 0.8666666666666667
# Precision = 0.75
# Recall = 0.75
# F1 Score = 0.75

# %% [markdown]
# #### Linear Support Vector Machine

# %%
# Create Linear Support Vector Machine classifier 
pipeline_svc, model_svc, prediction_svc, time_svc = initial_model(numcols,catcols, \
                                                                  LinearSVC(maxIter=10),train, test)
print('Linear Support Vector Machine Run time (mins): ',time_svc) 
acc_svc, f1_svc = evaluation(prediction_svc)
# Out:
# Linear Support Vector Machine Run time (mins):  2.2
# Summary Stats
# Accuracy = 0.9666666666666667
# Precision = 1.0
# Recall = 0.875
# F1 Score = 0.9333333333333333

# %% [markdown]
# #### Initial Models Performance Summary

# %%
# Model Performance summary for initial models
print('Performance Summary for initial models\n')
print("Logistic Regression model results: F1 Score {}, Accuracy is {}".format(f1_lr, acc_lr))
print("Random Forest model results: F1 Score {}, Accuracy is {}".format(f1_rf, acc_rf))
print("Gradient-boosted Tree model results: F1 Score {}, Accuracy is {}".format(f1_gbt, acc_gbt))
print("Linear Support Vector Machine results: F1 Score {}, Accuracy is {}".format(f1_svc, acc_svc))
# Out:
# Performance Summary for initial models
#
# Logistic Regression model results: F1 Score 0.867, Accuracy is 0.933
# Random Forest model results: F1 Score 0.692, Accuracy is 0.867
# Gradient-boosted Tree model results: F1 Score 0.75, Accuracy is 0.867
# Linear Support Vector Machine results: F1 Score 0.933, Accuracy is 0.967

# %% [markdown]
# ### Step 3. Conduct 3-fold cross validation and tune parameters.

# %%
# tune models
def model_tuning(pipeline,paramGrid,train = train, test = test):
    '''
    INPUT:
    pipeline - machine learning pipeline
    paramGrid - parameter grid for grid search
    train - train data
    test - test data
    
    OUTPUT:
    Model - fitted model based on train data
    prediction - predictions on test data
    run time in mins
    '''
    start = time.time()
    # Combining into VectorAssembler
    crossval = CrossValidator(estimator=pipeline,
                          estimatorParamMaps=paramGrid,
                          evaluator=MulticlassClassificationEvaluator(metricName='f1'),
                          numFolds=3)
    cvmodel = crossval.fit(train)
    #predict on test data
    cvprediction = cvmodel.transform(test)
    end = time.time()
    
    return cvmodel, cvprediction,round(round(end-start)/60,2)

# %%
# check grid search results 
def cvmodel_result(cvmodel):
    '''
    INPUT:
    Model - fitted model based on train data
    
    OUTPUT:
    p_df - pandas data frame of grid search results
    '''
    f1 = cvmodel.avgMetrics
    p_df = pd.DataFrame({p.name: v for p, v in param.items()} for param in cvmodel.getEstimatorParamMaps())
    p_df['f1'] = f1
    p_df = p_df.sort_values(by ='f1',ascending =False)
    
    return p_df

# %%
#feature importance
def feature_importance(cvmodel,metric):
    '''
    INPUT:
    Model - fitted model based on train data
    
    OUTPUT:
    f_df - pandas data frame of feature metric (importance)
    '''
    f_df = pd.DataFrame()
    feature = catcols + numcols
    f_df['feature'] = feature
    f_df['importance'] = metric 
    f_df = f_df.sort_values(by ='importance',ascending =False)

    return f_df

# %% [markdown]
# #### Logistic Regression Tuning
#  - maxIter (maximum number of iterations, default=100): [10, 30]
#  - threshold (Threshold in binary classification prediction, default = 0.5):[0.4, 0.5]
#  - elasticNetParam (the ElasticNet mixing parameter, 0 for L2 penalty, 1 for L1 penalty, default=0.0): [0.0, 1.0]

# %%
# Extract the summary from the returned LogisticRegressionModel instance trained
trainingSummary = model_lr.stages[-1].summary
# check the model threshold to maximize F-Measure
fMeasure = trainingSummary.fMeasureByThreshold
maxFMeasure = fMeasure.groupBy().max('F-Measure').select('max(F-Measure)').head()
bestThreshold = fMeasure.where(fMeasure['F-Measure'] == maxFMeasure['max(F-Measure)']) \
    .select('threshold').head()['threshold']
bestThreshold
# Out:
# 0.3781793207014142

# %%
# parameter grid: maxIter,threshold, the ElasticNet mixing parameter.
paramGrid_lr = ParamGridBuilder() \
    .addGrid(model_lr.stages[-1].maxIter,[10, 30]) \
    .addGrid(model_lr.stages[-1].threshold,[0.4,0.5]) \
    .addGrid(model_lr.stages[-1].elasticNetParam, [0.0,1.0]) \
    .build()

# %%
# tune the model
cvmodel_lr, cvprediction_lr, cvtime_lr = model_tuning(pipeline_lr,paramGrid_lr,train, test)
print('Logistic Regression Model Tuning time (mins): ',cvtime_lr)
cvacc_lr, cvf1_lr = evaluation(cvprediction_lr)
# F1 score on test data even decrease compared to the initial model. (overfitting on training data)
# Out:
# Logistic Regression Model Tuning time (mins):  67.23
# Summary Stats
# Accuracy = 0.9166666666666666
# Precision = 0.8666666666666667
# Recall = 0.8125
# F1 Score = 0.8387096774193549

# %%
# training model results
cvmodel_result(cvmodel_lr)
# Out:
#    maxIter  threshold  elasticNetParam        f1
# 6       30        0.5              0.0  0.910237
# 7       30        0.5              1.0  0.910237
# 4       30        0.4              0.0  0.904765
# 5       30        0.4              1.0  0.904765
# 2       10        0.5              0.0  0.894227
# 3       10        0.5              1.0  0.894227
# 0       10        0.4              0.0  0.883174
# 1       10        0.4              1.0  0.883174

# %%
# Coefficients
lr_imp = feature_importance(cvmodel_lr,cvmodel_lr.bestModel.stages[-1].coefficients)
lr_imp['odds'] = np.exp(lr_imp['importance'])
lr_imp.plot(kind ='barh',x ='feature',y='importance',color ='navy',legend=None,\
            title = 'Logistic Regression Coefficients',figsize = (12,8)).invert_yaxis();
plt.savefig('images/cvlr_coef.png')

# %% [markdown]
# #### Gradient-boosted Tree Tuning
#  - maxDepth (Maximum depth of the tree, default=5): [5, 10]
#  - minInstancesPerNode (Minimum number of instances each child must have after split, default=1): [1,3]

# %%
# parameter grid
paramGrid_gbt = ParamGridBuilder() \
    .addGrid(model_gbt.stages[-1].maxDepth, [5, 10]) \
    .addGrid(model_gbt.stages[-1].minInstancesPerNode,[1,3]) \
    .build()

# %%
# tune the model
cvmodel_gbt, cvprediction_gbt, cvtime_gbt = model_tuning(pipeline_gbt,paramGrid_gbt,train, test)
print('Gradient-boosted Tree Model Tuning time (mins): ',cvtime_gbt)
cvacc_gbt, cvf1_gbt = evaluation(cvprediction_gbt)
# Out:
# Gradient-boosted Tree Model Tuning time (mins):  49.85
# Summary Stats
# Accuracy = 0.8548387096774194
# Precision = 0.7333333333333333
# Recall = 0.6875
# F1 Score = 0.7096774193548386

# %%
# training model results
cvmodel_result(cvmodel_gbt)
# Out:
#    maxDepth  minInstancesPerNode        f1
# 3        10                    3  0.834527
# 0         5                    1  0.833799
# 2        10                    1  0.828218
# 1         5                    3  0.826676

# %%
#show feature importances
feature_importance(cvmodel_gbt,cvmodel_gbt.bestModel.stages[-1].featureImportances) \
.plot(kind ='bar',x ='feature',y='importance',color ='navy', \
      title = 'Gradient-boosted Tree Feature Importance');

# %% [markdown]
# #### Linear Support Vector Machine Tuning
#  - maxIter (maximum number of iterations, default=100): [10, 20]
#  - threshold (Threshold in binary classification prediction, default = 0.0):[0.0, -1, -5]

# %%
#default threshold
model_svc.stages[-1].getThreshold()
# Out:
# 0.0

# %%
# parameter grid
paramGrid_svc = ParamGridBuilder() \
    .addGrid(model_svc.stages[-1].maxIter, [10, 20]) \
    .addGrid(model_svc.stages[-1].threshold,[0.0,-1,-5]) \
    .build()

# %%
# tune the model
cvmodel_svc, cvprediction_svc, cvtime_svc = model_tuning(pipeline_svc,paramGrid_svc,train, test)
print('Gradient-boosted Tree Model Tuning time (mins): ',cvtime_svc)
cvacc_svc, cvf1_svc = evaluation(cvprediction_svc)
# Out:
# Gradient-boosted Tree Model Tuning time (mins):  27.93
# Summary Stats
# Accuracy = 0.9666666666666667
# Precision = 1.0
# Recall = 0.875
# F1 Score = 0.9333333333333333

# %%
# training model results
cvmodel_result(cvmodel_svc)
# Out:
#    maxIter  threshold        f1
# 0       10        0.0  0.896220
# 3       20        0.0  0.892343
# 4       20       -1.0  0.848259
# 1       10       -1.0  0.805067
# 5       20       -5.0  0.160780
# 2       10       -5.0  0.148497

# %%
#show feature importances
feature_importance(cvmodel_svc,cvmodel_svc.bestModel.stages[-1].coefficients) \
.plot(kind ='barh',x ='feature',y='importance',color ='navy',legend=None,\
      title = 'Linear Support Vector Machine Coefficients',figsize = (12,8)).invert_yaxis();
plt.savefig('images/cvsvc_coef.png')

# %%
### Random Forest 
# parameter grid
paramGrid_rf = ParamGridBuilder() \
    .addGrid(model_rf.stages[-1].minInstancesPerNode,[1,3]) \
    .addGrid(model_rf.stages[-1].numTrees, [20, 30]) \
    .build()
    
# tune the model
cvmodel_rf, cvprediction_rf, cvtime_rf = model_tuning(pipeline_rf,paramGrid_rf,train, test)
print('Random Forest Model Tuning time (mins): ',cvtime_rf)
cvacc_rf, cvf1_rf = evaluation(cvprediction_rf)    

# model results
print(cvmodel_result(cvmodel_rf))

#show feature importances
feature_importance(cvmodel_rf,cvmodel_rf.bestModel.stages[-1].featureImportances) \
.plot(kind ='bar',x ='feature',y='importance',color ='navy', \
      title = 'Random Forest Feature Importance');

# %% [markdown]
# #### Model Tuning Performance Summary
# Linear Support Vector Machine still has the highest F1 Score and accuracy on test data, but SVM might not be suitable for very large datasets. I would try Logistic Regression, Random Forest or Gradient-boosted Tree when deploying on the cloud.

# %%
# Model Performance summary for best tuned models
print('Performance Summary for best tuned models\n')
print("Logistic Regression model results: F1 Score {}, Accuracy is {}".format(cvf1_lr, cvacc_lr))
print("Linear Support Vector Machine results: F1 Score {}, Accuracy is {}".format(cvf1_svc, cvacc_svc))
# Out:
# Performance Summary for best tuned models
#
# Logistic Regression model results: F1 Score 0.839, Accuracy is 0.917
# Linear Support Vector Machine results: F1 Score 0.933, Accuracy is 0.967

# %% [markdown]
# ### Step 4. Implement three methods to treat imbalanced class issue.

# %% [markdown]
# The data have imblanced classes issue. So I try 3 different methods below to handle this.
# 1. Oversampling
# 2. Undersampling
# 3. Balancing class weights

# %%
# seperate minority/majority data
label1_df = df_user_clean.filter(df_user_clean.label == 1)
label0_df = df_user_clean.filter(df_user_clean.label == 0)

# %%
# calculate unbalanced ratio
ratio = label0_df.count()/ label1_df.count()
ratio
# Out:
# 3.326923076923077

# %% [markdown]
# #### 1. Oversampling

# %%
# duplicate the minority data (label1)
label1_os = label1_df.withColumn("dummy", explode(array([lit(x) for x in range(int(ratio))]))).drop('dummy')
# combine both oversampled minority label 1 and previous majority label 0
combined_os_df = label0_df.unionAll(label1_os)

# %%
#sample size before oversampling
df_user_clean.groupby('label').count().show()
# Out:
# +-----+-----+
# |label|count|
# +-----+-----+
# |    1|   52|
# |    0|  173|
# +-----+-----+

# %%
#sample size after oversampling
combined_os_df.groupby('label').count().show()
# Out:
# +-----+-----+
# |label|count|
# +-----+-----+
# |    1|  156|
# |    0|  173|
# +-----+-----+

# %%
#split the data
train_os, test_os = combined_os_df.randomSplit([0.7, 0.3], seed=42)
# Create logistic regression classifier
pipeline_lr_os, model_lr_os, prediction_lr_os, time_lr_os = initial_model(numcols,catcols, \
                                                              LogisticRegression(maxIter=10), \
                                                              train_os, test_os)
print('Logistic Regression Run time (mins): ',time_lr_os)
acc_lr_os, f1_lr_os = evaluation(prediction_lr_os)
#F1 score and accuracy on test data got improved compared to the initial model!
# Out:
# Logistic Regression Run time (mins):  3.07
# Summary Stats
# Accuracy = 0.8539325842696629
# Precision = 0.8636363636363636
# Recall = 0.8444444444444444
# F1 Score = 0.853932584269663

# %% [markdown]
# #### 2. Undersampling (might not work on the small dataset, but might be worth trying on large dataset)

# %%
#random delete some records from majority label 0
label0_us  = label0_df.sample(False, 1/ratio)
# combine both undersampled majority label 0 and previous minority label 1
combined_us_df = label1_df.unionAll(label0_us)
#sample size after oversampling (very tiny)
combined_us_df.groupby('label').count().show()
# Out:
# +-----+-----+
# |label|count|
# +-----+-----+
# |    1|   52|
# |    0|   54|
# +-----+-----+

# %%
#split the data
train_us, test_us = combined_us_df.randomSplit([0.7, 0.3], seed=42)
# Create logistic regression classifier
pipeline_lr_us, model_lr_us, prediction_lr_us, time_lr_us = initial_model(numcols,catcols, \
                                                              LogisticRegression(maxIter=10), \
                                                              train_us, test_us)
print('Logistic Regression Run time (mins): ',time_lr_us)
acc_lr_us, f1_lr_us = evaluation(prediction_lr_us)
#F1 score on test data got improved compared to the initial model!
# Out:
# Logistic Regression Run time (mins):  3.23
# Summary Stats
# Accuracy = 0.7575757575757576
# Precision = 0.7777777777777778
# Recall = 0.7777777777777778
# F1 Score = 0.7777777777777778

# %% [markdown]
# #### 3. Balancing class weights

# %%
#calculate class weights in pandas data frame
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
# class weight: n_samples / (n_classes * np.bincount(y)).
#### 3. Balancing class weightsy = pandas_df.label3. Balancing class weights
class_weights = {i: ii for i, ii in zip(np.unique(y), len(y) / (len(np.unique(y)) * np.bincount(y)))}
print(class_weights)
# Out:
# {0: 0.6502890173410405, 1: 2.1634615384615383}

# %%
#calculate class weights in spark data frame
y = df_user_clean.groupby('label').count().collect()
unique_y = [x["label"] for x in y]
total_y = df_user_clean.count()
unique_y_count = len(unique_y)
bin_count = [x["count"] for x in y]

class_weights_spark = {i: ii for i, ii in zip(unique_y, total_y / (unique_y_count * np.array(bin_count)))}
print(class_weights_spark)
# Out:
# {1: 2.1634615384615383, 0: 0.6502890173410405}

# %%
#create a mapping to apply a weight to each training instance.
mapping_weight = create_map([lit(x) for x in chain(*class_weights_spark.items())])
df_user_clean_weight = df_user_clean.withColumn("weight", mapping_weight.getItem(col("label")))

# %%
#check first record
df_user_clean_weight.head()
# Out:
# Row(userId='100010', label=0, female=1, upage_ct=11, tbup_ratio=0.04461942257217848, tbdw_ratio=0.013123359580052493, addfriend_ratio=0.010498687664041995, ad_ratio=0.13648293963254593, up_ratio=0.005249343832020997, help_ratio=0.005249343832020997, error_ratio=0.0, enroll_days=45, active_days=7, active_ratio=0.15555555555555556, uartist_pact=36.0, item_pses=54.42857142857143, weight=0.6502890173410405)

# %%
#split the data
train_wc, test_wc = df_user_clean_weight.randomSplit([0.7, 0.3], seed=42)
# Create logistic regression classifier
pipeline_lr_wc, model_lr_wc, prediction_lr_wc, time_lr_wc = initial_model(numcols,catcols, \
                                                              LogisticRegression(maxIter=10,weightCol="weight"), \
                                                              train_wc, test_wc)
print('Logistic Regression Run time (mins): ',time_lr_wc)
acc_lr_wc, f1_lr_wc = evaluation(prediction_lr_wc)
#F1 score on test data got improved compared to the initial model!
# Out:
# Logistic Regression Run time (mins):  2.02
# Summary Stats
# Accuracy = 0.8666666666666667
# Precision = 0.7222222222222222
# Recall = 0.8125
# F1 Score = 0.7647058823529411

# %% [markdown]
# #### Imbalanced classes fixing Performance Summary
# Oversampling method has improved the recall rate compared to initial model, but the f1 score and accuracy has not improved. Due to the data size, I would try undersampling and balancing class weights when deploying on the cloud.

# %%
# Model Performance summary for fixing imbalanced classes
print('Fixing Imbalanced Classes\n')
print("Initial Logistic Regression model results: F1 Score {}, Accuracy is {}".format(f1_lr, acc_lr))
print("1. Oversampling: F1 Score {}, Accuracy is {}".format(f1_lr_os, acc_lr_os))
print("2. Undersampling: F1 Score {}, Accuracy is {}".format(f1_lr_us, acc_lr_us))
print("3. Balancing class weights: F1 Score {}, Accuracy is {}".format(f1_lr_wc, acc_lr_wc))
# Out:
# Fixing Imbalanced Classes
#
# Initial Logistic Regression model results: F1 Score 0.867, Accuracy is 0.933
# 1. Oversampling: F1 Score 0.854, Accuracy is 0.854
# 2. Undersampling: F1 Score 0.778, Accuracy is 0.758
# 3. Balancing class weights: F1 Score 0.765, Accuracy is 0.867

# %% [markdown]
# F1 Score has improved for all three methods to deal with imbalanced classes:
#
# | Category | F1 Score | Accuracy |
# | --- | --- | --- |
# | Initial Data | 0.867 | 0.933|
# | Oversampling | 0.854 | 0.854|
# | Undersampling | 0.778 | 0.758|
# | Balancing class weights | 0.765 | 0.867|
